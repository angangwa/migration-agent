# %% [markdown]
# # Semantic Kernel Multi-Agent Orchestration
#
# Welcome to the multi-agent orchestration tutorial! This notebook explores different patterns for coordinating multiple AI agents working together.
#
# ## Prerequisites
#
# Before starting this tutorial, make sure you've completed:
# - **Semantic Kernel Basics** notebook
# - **Advanced Agent Features** notebook
#
# You should be familiar with:
# - Agent creation and configuration
# - Plugins and function calling
# - Streaming responses and intermediate steps
# - Structured outputs
#
# ## What You'll Learn
#
# - **Group Chat Orchestration**: Round-robin and custom managers
# - **Concurrent Processing**: Parallel agent execution
# - **Sequential Workflows**: Pipeline-based processing
# - **Handoff Systems**: Specialized agent routing
# - **Human-in-the-Loop**: Interactive agent workflows
#
# ## Resources
# - [Agent Framework Guide](https://learn.microsoft.com/en-us/semantic-kernel/frameworks/agent/)
#
# Let's explore multi-agent orchestration patterns!

# %% [markdown]
# ## Setup and Imports
#
# Let's start by importing all the necessary modules for orchestration.

# %%
import asyncio
import json
from typing import Annotated
import os
from dotenv import load_dotenv
from pydantic import BaseModel

# Core Semantic Kernel imports
from semantic_kernel import Kernel
from semantic_kernel.agents import Agent, ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion, OpenAIChatCompletion
from semantic_kernel.connectors.ai.open_ai import OpenAIChatPromptExecutionSettings, AzureChatPromptExecutionSettings
from semantic_kernel.functions import kernel_function, KernelArguments
from semantic_kernel.contents import ChatMessageContent, TextContent, StreamingChatMessageContent
from semantic_kernel.contents.utils.author_role import AuthorRole
from semantic_kernel.contents.chat_history import ChatHistory
from semantic_kernel.contents import FunctionCallContent, FunctionResultContent

# Orchestration imports
from semantic_kernel.agents import (
    GroupChatOrchestration, 
    RoundRobinGroupChatManager,
    ConcurrentOrchestration,
    SequentialOrchestration,
    HandoffOrchestration,
    OrchestrationHandoffs
)
from semantic_kernel.agents.runtime import InProcessRuntime
from semantic_kernel.agents.orchestration.tools import structured_outputs_transform
from semantic_kernel.agents.orchestration.group_chat import BooleanResult, GroupChatManager, MessageResult, StringResult
from semantic_kernel.connectors.ai.prompt_execution_settings import PromptExecutionSettings
from semantic_kernel.prompt_template import KernelPromptTemplate, PromptTemplateConfig
from typing_extensions import override

# Additional imports for LLM-based group chat manager
from semantic_kernel.connectors.ai.chat_completion_client_base import ChatCompletionClientBase

# Load environment variables
load_dotenv()

print("✅ Orchestration imports loaded successfully!")

# %%
# Configure the main chat completion service
chat_completion = AzureChatCompletion(
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    deployment_name=os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME"),
)

print("✅ Chat completion service configured!")
# Out:
# ✅ Chat completion service configured!

# %% [markdown]
# ## 1. Group Chat Orchestration
#
# Group chat orchestration allows multiple agents to participate in a conversation, taking turns based on a management strategy.

# %% [markdown]
# ### 1.1 Round Robin Group Chat
#
# Round robin orchestration ensures agents take turns in a specific order.

# %%
def create_content_team() -> list[Agent]:
    """Create a team of content creation agents."""
    
    writer = ChatCompletionAgent(
        name="ContentWriter",
        description="A creative content writer.",
        instructions="You create engaging content. Focus on creativity and readability.",
        service=chat_completion,
    )
    
    editor = ChatCompletionAgent(
        name="ContentEditor",
        description="A content editor and reviewer.",
        instructions="You review and improve content. Focus on clarity, grammar, and flow.",
        service=chat_completion,
    )
    
    return [writer, editor]

def agent_response_callback(message: ChatMessageContent) -> None:
    """Display agent responses with truncation for cleaner logs."""
    print(f"**{message.name}**")
    
    # Truncate long responses for cleaner output
    content = message.content
    if len(content) > 500:
        content = content[:500] + "... [truncated]"
    
    print(content)
    print("-" * 50)

# Create the group chat
content_agents = create_content_team()
group_chat = GroupChatOrchestration(
    members=content_agents,
    manager=RoundRobinGroupChatManager(max_rounds=3),
    agent_response_callback=agent_response_callback,
)

print("✅ Group chat orchestration created!")
# Out:
# ✅ Group chat orchestration created!

# %%
# Test group chat orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Task: Create content for a sustainable living blog post")
print("=" * 60)

try:
    orchestration_result = await group_chat.invoke(
        task="Create a compelling blog post about sustainable living tips for busy professionals.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get()
    print(f"\n**Final Result**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Task: Create content for a sustainable living blog post
# ============================================================
# **ContentWriter**
# Sustainable Living for Busy Professionals: Simple Tips You Can Start Today
#
# Introduction
# Juggling work deadlines, family commitments, and a social life can leave little room for eco-friendly choices. Yet, even small sustainable changes can make a big difference—both for the planet and your own well-being. Here’s how busy professionals can weave green habits into a packed schedule.
#
# 1. Plan Your Meals, Waste Less
#   • Weekly Meal Prep: Spend one hour on Sunday chopping vegetables, cooking grains, and portioning meals. Homemade lunches reduce takeout packaging and save money.
#   • Smart Shopping Lists: Check your pantry before making a list. Buy only what you need to avoid food waste.
#   • Zero-Waste Snacking: Invest in reusable snack bags or glass jars. Fill them with nuts, fruit, or trail mix before you dash out the door.
#
# 2. Transform Your Commute
#   • Carpool or Ride-Share: Coordinate with a coworker or a neighbor to share the drive. Fewer cars on the road mean lower emissions—and you’ll split the cost of fuel.
#   • Public Transit and E-Bikes: If timing allows, trade your solo commute for a bus, train, or electric bike. You’ll get fresh air, skip parking hassles, and shrink your carbon footprint.
#   • Walking Meetings: When agreeable, turn short office discussions into strolls around the block. Fresh air boosts creativity and health.
#
# 3. Create an Eco-Friendly Workspace
#   • Go Paperless: Scan invoices, contracts, and notes. Use digital tools like cloud storage and collaborative apps to keep everything organized online.
#   • Energy-Efficient Equipment: Choose LED lighting, ENERGY STAR–rated monitors, and laptops. Turn off devices overnight—set power-saving modes if you’re forgetful.
#   • Green Office Décor: Add a low-maintenance plant or two. They purify the air and reduce stress. Succulents, pothos, and snake plants thrive even on busy office days.
#
# 4. Mindful Shopping and Wardrobe Swaps
#   • Capsule Wardrobe: Assemble a small collection of versatile, high-quality pieces you love. Fewer purchases mean less textile waste and easier mornings.
#   • Secondhand and Rental Services: Try a clothing rental for special events or shop at thrift stores online. You’ll save money and give garments a second life.
#   • Eco-Friendly Brands: When you do buy new, look for labels that use organic fabrics, fair-trade practices, or recycled materials.
#
# 5. Harness Technology for Good
#   • Sustainability Apps: Track your carbon footprint, find local recycling centers, and get reminders to switch off lights. Apps like “Oroeco” or “JouleBug” turn eco-choices into a fun challenge.
#   • Smart Thermostats and Plugs: Program heating or cooling to match your daily routine. Set smart plugs to power down devices when you’re out or asleep.
#   • Virtual Networking: Attend webinars, conferences, or happy hours in your PJs. You’ll cut travel emissions and still build meaningful connections.
#
# 6. Swap Single-Use for Reusables
#   • Coffee Cup Habit: Carry an insulated mug or collapsible cup for your daily latte. Many cafes even offer discounts for bringing your own.
#   • Water Bottles and Utensils: Keep a stainless-steel bottle and bamboo utensil set in your bag. You’ll avoid plastic straws and cutlery at restaurants.
#   • Refillable Cleaning Stations: Install refill pumps for soap, shampoo, and cleaning detergents. Bulk refill packs reduce plastic waste—and often cost less over time.
#
# 7. Embrace Community and Accountability
#   • Green Challenges: Invite friends or coworkers to a 30-day sustainability challenge. Whether it’s “no-plastic week” or “meatless Mondays,” shared goals build momentum.
#   • Volunteer Locally: Spend a Saturday morning planting trees, picking up litter, or helping at a community garden. You’ll meet like-minded people and recharge your sense of purpose.
#   • Share Your Wins: Post eco-hacks on social media or start a newsletter for your office. Celebrating small victories inspires others to join in.
#
# Conclusion
# Sustainable living doesn’t require a complete lifestyle overhaul—just a series of small, consistent steps. As a busy professional, you can start by integrating one or two tips this week and then build on your successes. Over time, these eco-friendly habits will become second nature, saving you time, money, and stress, while contributing to a healthier planet. Ready to take the first step? Pick one tip from this list and watch the ripple effect begin.
# --------------------------------------------------
# **ContentEditor**
# Sustainable Living for Busy Professionals: 7 Simple Tips to Get Started Today
#
# Introduction
# Between back-to-back meetings, tight deadlines, and a social life to maintain, eco-friendly choices can feel like one more thing on your to-do list. The good news? Small, intentional changes add up fast—saving you time, money, and stress while shrinking your carbon footprint. Here’s how you can weave green habits into your hectic routine without sacrificing productivity.
#
# 1. Plan Your Meals and Cut Food Waste
#   • Weekly Meal Prep: Dedicate one hour on Sunday to chop veggies, cook grains, and portion lunches. You’ll dodge last-minute takeout and curb packaging waste.
#   • Smart Shopping Lists: Audit your pantry before you shop. Buying only what you need helps eliminate expired items and save money.
#   • Zero-Waste Snacks: Pack reusable snack bags or glass jars with nuts, fruit, or trail mix so you’re never tempted by single-use packaging.
#
# 2. Rethink Your Commute
#   • Carpool or Ride-Share: Coordinate with a coworker or neighbor. You’ll halve fuel costs, reduce traffic, and lower emissions.
#   • Public Transit & E-Bikes: Swap your solo drive for a bus, train, or electric bike. You’ll skip parking hassles, get a bit of exercise, and shrink your carbon footprint.
#   • Walking Meetings: Turn quick check-ins into strolls around the block. Fresh air sparks creativity and boosts energy more than a conference room ever could.
#
# 3. Build an Eco-Friendly Workspace
#   • Go Paperless: Scan invoices, notes, and contracts. Use cloud storage and digital collaboration tools to keep everything organized—no paper jam required.
#   • Energy-Efficient Gear: Opt for LED lights and ENERGY STAR–rated monitors or laptops. Enable power-saving modes and shut down devices at day’s end.
#   • Green Décor: Place a low-maintenance plant—like a succulent or pothos—on your desk. Plants improve air quality and reduce stress, even in a busy office.
#
# 4. Simplify Your Wardrobe Choices
#   • Capsule Collection: Curate a handful of versatile, high-quality pieces you love. Fewer—but better—choices mean less closet clutter and faster mornings.
#   • Secondhand & Rental: Reserve special-occasion outfits through clothing-rental platforms or browse thrift stores online. You’ll save money and extend a garment’s life.
#   • Conscious Brands: When you buy new, look for organic fabrics, fair-trade certifications, or recycled materials.
#
# 5. Leverage Smart Tech for Sustainable Living
#   • Eco-Apps: Use apps like “Oroeco” or “JouleBug” to track your carbon footprint, locate recycling centers, and set energy-saving reminders. Turning eco-choices into a game keeps you motivated.
#   • Smart Thermostats & Plugs: Automate heating and cooling to match your schedule. Program smart plugs to power down unused devices overnight or when you’re away.
#
# 6. Choose Reusables Over Single-Use
#   • Bring Your Own Mug: Carry an insulated cup for coffee runs—many cafés even reward reusable orders with a discount.
#   • Refillable Essentials: Keep a stainless-steel water bottle and a bamboo utensil set handy. You’ll bypass plastic straws and disposable cutlery.
#   • Bulk Refill Stations: Refill soaps, shampoos, and cleaning supplies from bulk dispensers to cut down on plastic bottles—and often save money.
#
# 7. Connect, Collaborate, and Celebrate
#   • Green Challenges: Launch a “meatless Mondays” or “no-plastic week” with friends or coworkers. Shared goals create accountability and camaraderie.
#   • Volunteer Locally: Join tree plantings, beach clean-ups, or community garden projects on weekends. You’ll meet like-minded people and strengthen your sense of purpose.
#   • Share Your Successes: Post eco-hacks on social media, start an office newsletter, or host a quick lunch-and-learn. Celebrating small wins encourages others to jump on board.
#
# Conclusion
# Sustainable living doesn’t require a massive lifestyle overhaul—it thrives on small, consistent actions. Pick one tip from this list and commit to it this week. As these habits take root, you’ll save time, cut expenses, and feel more energized—all while doing your part for a healthier planet. Ready to get started? Choose your first step today and watch the ripple effect grow.
# --------------------------------------------------
# **ContentWriter**
# Sustainable Living for Busy Professionals: 7 Simple Tips to Make a Big Impact
#
# Introduction
# Between tight deadlines, back-to-back meetings, and a social life that demands your attention, going green can seem like yet another item on your overflowing to-do list. The truth is, small, intentional changes add up quickly—helping the planet, lowering your expenses, and boosting your energy. Here are seven straightforward strategies you can start this week, no matter how hectic your schedule.
#
# 1. Plan Your Meals and Reduce Food Waste
# • Weekly Meal Prep: Block out just 30–60 minutes on a weekend or in the evening to chop vegetables, cook grains, and assemble lunches. Homemade meals cut packaging waste and curb impulse takeout orders.
# • Smart Shopping Lists: Before you head to the store, take inventory of what’s already in your fridge and pantry. Buying only what you need helps you avoid spoiled produce and extra trips.
# • Zero-Waste Snacking: Keep reusable snack bags or glass jars on hand. Fill them with trail mix, chopped fruit, or veggie sticks so you’re never tempted by single-use packaging.
#
# 2. Rethink Your Commute
# • Carpool or Ride-Share: Partner with a coworker or neighbor who travels a similar route. You’ll split fuel costs, reduce traffic, and lower carbon emissions.
# • Public Transit & E-Bikes: If your schedule allows, swap part or all of your drive for a bus, train, or electric bike ride. You’ll skip parking headaches, sneak in light exercise, and shrink your footprint.
# • Walking Meetings: For quick one-on-ones or brainstorming sessions, suggest a brief walk around the block. Fresh air sparks creativity and wellness far better than fluorescent lights.
#
# 3. Build an Eco-Friendly Workspace
# • Go Paperless: Scan receipts, contracts, and handwritten notes. Use cloud storage and collaboration tools to keep documents at your fingertips without physical files.
# • Energy-Efficient Equipment: Choose LED desk lamps, ENERGY STAR–rated monitors, and laptops. Activate power-saving modes and switch off devices at the end of the day.
# • Bring Nature In: Place a low-maintenance plant—like a pothos, snake plant, or succulent—on your desk. Plants improve air quality, reduce stress, and require minimal care.
#
# 4. Simplify Your Wardrobe Choices
# • Capsule Collection: Curate a small set of high-quality, versatile pieces you genuinely love. Fewer—but better—options mean a quicker morning routine and less fashion waste.
# • Secondhand & Rental Services: For special events or seasonal refreshes, explore clothing-rental platforms and online thrift shops. You’ll save money and extend the lifespan of garments.
# • Support Sustainable Brands: When you do shop new, look for organic or recycled fabrics, fair-trade certifications, and transparent manufacturing practices.
#
# 5. Leverage Smart Tech for Good
# • Sustainability Apps: Download tools like JouleBug, Oroeco or Giki that track your carbon footprint, locate recycling facilities, and turn eco-habits into fun challenges.
# • Smart Thermostats & Plugs: Automate your home’s heating or cooling based on your routine. Set smart plugs to power down devices when you’re out or asleep, reducing phantom energy use.
#
# 6. Choose Reusables Over Single-Use
# • BYO Coffee Cup: Carry an insulated mug or collapsible cup for coffee runs. Many cafes even offer discounts for customers who bring their own.
# • Refill, Don’t Replace: Install bulk dispensers for soap, shampoo, and cleaning supplies. Refillable containers cut plastic waste and often cost less over time.
# • Portable Cutlery and Bottles: Keep a stainless-steel water bottle and bamboo utensil set in your bag. Avoid plastic straws and disposable flatware whenever you’re on the go.
#
# 7. Connect, Collaborate, Celebrate
# • Team Green Challenges: Invite colleagues or friends to a “meatless Monday,” a car-free day, or a no-plastic week. Shared goals and friendly competition keep everyone motivated.
# • Volunteer Locally: Dedicate a weekend morning to tree plantings, park cleanups, or community gardens. You’ll meet like-minded neighbors and feel the satisfaction of hands-on impact.
# • Showcase Your Wins: Share your eco-hacks on social media, start an office newsletter, or host a quick lunchtime demo. Celebrating small victories encourages others to join the movement.
#
# Conclusion
# Sustainable living doesn’t require a total lifestyle overhaul—just a series of small, consistent steps. Pick one tip from this list and commit to it for the next seven days. As each green habit takes root, you’ll save time, reduce costs, and feel more energized, all while making a meaningful contribution to our planet’s future. Ready to get started? Choose your first step today and watch the positive ripple effect unfold.
# --------------------------------------------------
#
# **Final Result**
# Sustainable Living for Busy Professionals: 7 Simple Tips to Make a Big Impact
#
# Introduction
# Between tight deadlines, back-to-back meetings, and a social life that demands your attention, going green can seem like yet another item on your overflowing to-do list. The truth is, small, intentional changes add up quickly—helping the planet, lowering your expenses, and boosting your energy. Here are seven straightforward strategies you can start this week, no matter how hectic your schedule.
#
# 1. Plan Your Meals and Reduce Food Waste
# • Weekly Meal Prep: Block out just 30–60 minutes on a weekend or in the evening to chop vegetables, cook grains, and assemble lunches. Homemade meals cut packaging waste and curb impulse takeout orders.
# • Smart Shopping Lists: Before you head to the store, take inventory of what’s already in your fridge and pantry. Buying only what you need helps you avoid spoiled produce and extra trips.
# • Zero-Waste Snacking: Keep reusable snack bags or glass jars on hand. Fill them with trail mix, chopped fruit, or veggie sticks so you’re never tempted by single-use packaging.
#
# 2. Rethink Your Commute
# • Carpool or Ride-Share: Partner with a coworker or neighbor who travels a similar route. You’ll split fuel costs, reduce traffic, and lower carbon emissions.
# • Public Transit & E-Bikes: If your schedule allows, swap part or all of your drive for a bus, train, or electric bike ride. You’ll skip parking headaches, sneak in light exercise, and shrink your footprint.
# • Walking Meetings: For quick one-on-ones or brainstorming sessions, suggest a brief walk around the block. Fresh air sparks creativity and wellness far better than fluorescent lights.
#
# 3. Build an Eco-Friendly Workspace
# • Go Paperless: Scan receipts, contracts, and handwritten notes. Use cloud storage and collaboration tools to keep documents at your fingertips without physical files.
# • Energy-Efficient Equipment: Choose LED desk lamps, ENERGY STAR–rated monitors, and laptops. Activate power-saving modes and switch off devices at the end of the day.
# • Bring Nature In: Place a low-maintenance plant—like a pothos, snake plant, or succulent—on your desk. Plants improve air quality, reduce stress, and require minimal care.
#
# 4. Simplify Your Wardrobe Choices
# • Capsule Collection: Curate a small set of high-quality, versatile pieces you genuinely love. Fewer—but better—options mean a quicker morning routine and less fashion waste.
# • Secondhand & Rental Services: For special events or seasonal refreshes, explore clothing-rental platforms and online thrift shops. You’ll save money and extend the lifespan of garments.
# • Support Sustainable Brands: When you do shop new, look for organic or recycled fabrics, fair-trade certifications, and transparent manufacturing practices.
#
# 5. Leverage Smart Tech for Good
# • Sustainability Apps: Download tools like JouleBug, Oroeco or Giki that track your carbon footprint, locate recycling facilities, and turn eco-habits into fun challenges.
# • Smart Thermostats & Plugs: Automate your home’s heating or cooling based on your routine. Set smart plugs to power down devices when you’re out or asleep, reducing phantom energy use.
#
# 6. Choose Reusables Over Single-Use
# • BYO Coffee Cup: Carry an insulated mug or collapsible cup for coffee runs. Many cafes even offer discounts for customers who bring their own.
# • Refill, Don’t Replace: Install bulk dispensers for soap, shampoo, and cleaning supplies. Refillable containers cut plastic waste and often cost less over time.
# • Portable Cutlery and Bottles: Keep a stainless-steel water bottle and bamboo utensil set in your bag. Avoid plastic straws and disposable flatware whenever you’re on the go.
#
# 7. Connect, Collaborate, Celebrate
# • Team Green Challenges: Invite colleagues or friends to a “meatless Monday,” a car-free day, or a no-plastic week. Shared goals and friendly competition keep everyone motivated.
# • Volunteer Locally: Dedicate a weekend morning to tree plantings, park cleanups, or community gardens. You’ll meet like-minded neighbors and feel the satisfaction of hands-on impact.
# • Showcase Your Wins: Share your eco-hacks on social media, start an office newsletter, or host a quick lunchtime demo. Celebrating small victories encourages others to join the movement.
#
# Conclusion
# Sustainable living doesn’t require a total lifestyle overhaul—just a series of small, consistent steps. Pick one tip from this list and commit to it for the next seven days. As each green habit takes root, you’ll save time, reduce costs, and feel more energized, all while making a meaningful contribution to our planet’s future. Ready to get started? Choose your first step today and watch the positive ripple effect unfold.

# %% [markdown]
# ## 2. Concurrent Orchestration
#
# Concurrent orchestration allows multiple agents to work on the same task simultaneously.

# %%
def create_research_team() -> list[Agent]:
    """Create a team of research specialists."""
    
    tech_researcher = ChatCompletionAgent(
        name="TechResearcher",
        instructions="You are a technology research expert. Analyze questions from a technical perspective.",
        service=chat_completion,
    )
    
    market_researcher = ChatCompletionAgent(
        name="MarketResearcher",
        instructions="You are a market research expert. Analyze questions from a business and market perspective.",
        service=chat_completion,
    )
    
    return [tech_researcher, market_researcher]

# Create concurrent orchestration
research_agents = create_research_team()
concurrent_orchestration = ConcurrentOrchestration(members=research_agents)

print("✅ Concurrent orchestration created!")
# Out:
# ✅ Concurrent orchestration created!

# %%
# Test concurrent orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Research Topic: Electric Vehicle Market")
print("=" * 50)

try:
    orchestration_result = await concurrent_orchestration.invoke(
        task="Analyze the current state and future prospects of the electric vehicle market.",
        runtime=runtime,
    )
    
    results = await orchestration_result.get(timeout=60)
    
    for result in results:
        print(f"**{result.name}**")
        print(result.content)
        print("-" * 50)
        
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Research Topic: Electric Vehicle Market
# ==================================================
# **TechResearcher**
# Below is an overview of where the global electric-vehicle (EV) market stands today, the main drivers and barriers it faces, and the key trends likely to shape its evolution over the next decade.
#
# 1. Market Size and Growth
# • Global Sales and Penetration
#   – In 2023, roughly 14–16% of new-vehicle sales worldwide were battery electric vehicles (BEVs), up from about 4% in 2020. Plug-in hybrids (PHEVs) added another 4–5%.
#   – China leads with more than half of global EV sales, followed by Europe (~30%) and North America (~15%).
# • Manufacturers and Models
#   – Tesla remains the top BEV seller by volume, but legacy automakers (Volkswagen Group, Stellantis, Hyundai-Kia, GM, Ford) are rapidly ramping dedicated EV platforms.
#   – New entrants (NIO, XPeng, Rivian, BYD) are expanding beyond home markets.
#
# 2. Key Enablers Today
# • Battery Cost Declines
#   – Average pack prices fell from ~$1,100/kWh in 2010 to ~$135/kWh in 2022, largely thanks to scale-up of lithium-ion production in China and improved cell chemistries.
# • Policy and Incentives
#   – Purchase subsidies, tax breaks and zero-emission vehicle mandates in Europe, China, California and select other regions.
#   – ICE bans or phase-outs announced for 2030–2040 in the EU, UK, Canada and several U.S. states.
# • Charging Infrastructure
#   – Public fast chargers grew at a 25%+ annual rate. China has >1 million public chargers; Europe has ~500,000. North America trails at ~100,000 but is accelerating build-out.
#
# 3. Ongoing Challenges
# • Raw-Material and Supply-Chain Constraints
#   – Lithium, cobalt, nickel and manganese supply risks could create bottlenecks or cost spikes. Securing diversified sources and developing recycling/second-life flows is critical.
# • Grid and Charger Utilization
#   – High-power DC fast-charging can strain local grids; managed charging, vehicle-to-grid (V2G) and energy-storage buffering solutions are still emerging.
# • Total Cost of Ownership (TCO) Parity
#   – Although battery costs have plunged, higher upfront prices and consumer concerns over range, charging time and battery degradation remain hurdles in some segments.
# • Standardization and Interoperability
#   – Multiple charging connectors (CCS, GB/T, CHAdeMO) and payment models slow seamless cross-border and public/private charging access.
#
# 4. Technology Trends to Watch
# • Next-Gen Batteries
#   – Solid-state, silicon-anode and Li-sulfur chemistries promise higher energy density (300–500 Wh/kg), faster charging and improved safety by late decade.
# • Fast Charging and Ultra-High Power (UHP)
#   – 350+kW chargers are entering the market, capable of 100+ miles of range in 5–10 minutes under optimal conditions.
# • Software, Connectivity and Autonomy
#   – Over-the-air updates, integrated telematics, advanced driver-assistance systems (ADAS) and eventual Level-4/5 automation will add value but also complexity and regulatory scrutiny.
# • Vehicle-to-Everything (V2X)
#   – Bi-directional charging (V2G), smart-home integration and grid services could unlock new revenue streams and boost renewable-energy adoption.
#
# 5. Future Prospects and Forecasts
# • Market Share Projections
#   – By 2025: BEVs may represent 20–25% of new-car sales globally; by 2030: 50–60% or more, assuming continued policy support and cost reductions.
# • Total Cost of Ownership
#   – Forecast breakeven of EV vs. internal-combustion TCO for many segments as early as 2025–2027, driven by further battery-cost declines and economies of scale.
# • New Business Models
#   – Battery leasing, subscription services, fleet electrification (rideshare, delivery) and mobility-as-a-service (MaaS) platforms will accelerate adoption in urban centers.
# • Regional Variations
#   – China and Europe likely reach 70–80% BEV share by 2030; North America may be closer to 50–60%, constrained by broader geographic charging needs and slower policy roll-outs.
#
# 6. Risks and Wild Cards
# • Commodities and Geopolitics
#   – Export controls, trade disputes or price surges in lithium/nickel/cobalt could slow battery deployment.
# • Technological Disruption
#   – Hydrogen fuel-cell vehicles, advanced synthetic fuels or breakthroughs in internal-combustion efficiency could alter the competitive landscape in heavy-duty and long-haul sectors.
# • Consumer Sentiment and Economic Cycles
#   – Interest-rate movements, vehicle-price inflation and shifting consumer preferences (e.g., toward affordability over zero-emission) may delay some adoption curves.
#
# Conclusion
# The electric-vehicle market is on a steep growth trajectory driven by rapid improvements in battery technology, strong policy support and ever-expanding charging infrastructure. Over the next decade, cost parity, next-generation chemistries and software-defined vehicle features will determine winners and losers. While supply-chain resilience, grid integration and standardization remain challenges, EVs are poised to become the dominant powertrain choice in passenger cars—and increasingly in commercial and specialty vehicles—by 2030.
# --------------------------------------------------
# **MarketResearcher**
# Below is a structured, business- and market-oriented overview of the electric vehicle (EV) market today and its likely evolution over the next five to ten years.
#
# 1. Executive Summary
#  • Global EV stock has grown rapidly, reaching roughly 16 million vehicles in use by end-2023 (up from 10 million in 2020).
#  • Share of new-vehicle sales is now about 15–20 percent globally, with peaks above 25 percent in markets such as China, Norway and Germany.
#  • Most analysts project global EV penetration of new sales to reach 30–40 percent by 2030.
#
# 2. Current Market Landscape
#  A. Market Size and Growth
#    – 2023 global EV sales: ~12 million (up ~35 percent year-on-year).
#    – Total market value of EVs, batteries and related services: ~US $350 billion in 2023.
#    – Leading segments: passenger BEVs (~80 percent of EV sales), PHEVs (~15 percent), commercial/light-dive vans and buses (~5 percent).
#
#  B. Regional Breakdown
#    – China: ~60 percent of global EV volume. Strong state support, local champions (BYD, SAIC, Geely).
#    – Europe: ~25 percent share; aggressive CO₂ targets, nation-level purchase incentives. Key players: Volkswagen, Stellantis, BMW, Volvo.
#    – North America: ~10 percent share; Tesla dominates (~50 percent U.S. BEV market), Detroit OEMs scaling up.
#
#  C. Key Drivers
#    – Regulatory push: ICE bans/phase-outs in EU, UK, California by 2035–2040.
#    – Total cost of ownership parity: Battery costs have fallen below US $130/kWh, driving TCO in line with ICE in many markets.
#    – Consumer awareness: Growing environmental consciousness and positive perceptions on performance and convenience.
#
#  D. Main Challenges
#    – Charging infrastructure: Gaps in public fast-charging networks, slow roll-out in emerging markets.
#    – Supply-chain constraints: Critical minerals (lithium, cobalt, nickel) concentrated in a few countries; geopolitical risk.
#    – Grid impacts: Need for smart charging, demand-response and grid investments to handle peak loads.
#    – Residual-value uncertainty and secondary-market development still maturing.
#
# 3. Competitive & Technology Landscape
#  A. OEMs and New Entrants
#    – Incumbents scaling EV portfolios (VW ID-series, GM Ultium, Hyundai-Kia, Ford Mustang Mach-E).
#    – Pure-play startups: Tesla remains #1; China’s BYD, NIO, Xpeng, Li Auto gaining share; Rivian and Lucid in premium U.S. segments.
#    – Tier-1 suppliers investing in battery packs, electric drivetrains, power electronics.
#
#  B. Battery and Propulsion Technologies
#    – NCM/NCA lithium-ion still dominant; LFP growing in cost-sensitive mass market (especially in China).
#    – Next-gen chemistries (silicon-anode, semi-solid, solid-state) targeting higher energy density and faster charging.
#    – Fuel-cell EVs limited to heavy-duty or niche use (buses, trucks) because of H2 infrastructure challenges.
#
#  C. Digital & Services Ecosystem
#    – Over-the-air software updates, in-car connectivity and subscription-based features (autonomous-assistance, infotainment).
#    – Fleet management, vehicle-to-grid (V2G) and second-life battery services emerging as value pools.
#
# 4. Future Prospects & Forecasts
#  A. Market Growth
#    – Global EV stock forecast to exceed 70 million by 2030.
#    – Annual new-vehicle EV share to approach 30–40 percent by 2030, reaching parity with ICE vehicles in key markets.
#    – Global EV market revenues (vehicles, batteries, charging) projected at US $600–700 billion by 2030.
#
#  B. Key Trends
#    – Continued battery-cost declines toward US $100/kWh or lower.
#    – Expansion of ultra-fast (150–350 kW) public charging networks and interoperable charging standards.
#    – Vertical integration of OEMs into battery manufacturing and raw-material sourcing.
#    – Emergence of EV-only platforms, with increasingly modular, software-defined architectures.
#    – Growth of electric commercial vehicles and last-mile delivery fleets; electrification of heavy trucks by early 2030s.
#
#  C. Risk Factors
#    – Raw-material price volatility and concentration risk (e.g., cobalt in DRC).
#    – Potential policy rollback or slower incentive phases-out leading to softening demand.
#    – Grid stability constraints where renewables and EV charging coincide without smart management.
#    – Competitive pressures compressing margins as OEMs overinvest and price wars emerge.
#
# 5. Strategic Implications for Businesses
#  • Automakers: Accelerate platform commonality, secure raw-materials, expand charging partnerships, pursue software and services monetization.
#  • Suppliers: Focus on differentiated battery‐cell technologies, power electronics, thermal management, digital prognostics.
#  • Charging‐network operators & utilities: Invest in fast infrastructure, integrate renewables, develop dynamic pricing and V2G offerings.
#  • Investors & financial institutions: Evaluate supply-chain projects (mining, refining), charging infrastructure and e-mobility service platforms for long-term returns.
#
# 6. Conclusion
# The electric-vehicle market is at an inflection point. Strong regulatory backing, rapidly improving economics and consumer acceptance underpin continued double-digit growth over the next decade. Success will hinge on managing supply-chain risks, scaling charging and software capabilities, and navigating intensified competition among OEMs and new entrants. Careful alignment of technology, policy and business models will determine which players capture the largest share of this transformational market.
# --------------------------------------------------

# %% [markdown]
# ### 2.1 Concurrent Orchestration with Structured Outputs
#
# You can combine concurrent orchestration with structured outputs for consistent results.

# %%
# Define structured output for research
class ResearchInsight(BaseModel):
    """Research insight with key findings."""
    key_finding: str
    supporting_evidence: str
    implications: str

class ResearchPerspectives(BaseModel):
    """Combined research perspectives."""
    technology: ResearchInsight
    market: ResearchInsight

# Create structured concurrent orchestration
structured_concurrent = ConcurrentOrchestration[str, ResearchPerspectives](
    members=research_agents,
    output_transform=structured_outputs_transform(ResearchPerspectives, chat_completion),
)

print("✅ Structured concurrent orchestration created!")
# Out:
# ✅ Structured concurrent orchestration created!

# %%
# Test structured concurrent orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Structured Research: AI in Healthcare")
print("=" * 50)

try:
    orchestration_result = await structured_concurrent.invoke(
        task="Research AI applications in healthcare. Provide key finding, evidence, and implications.",
        runtime=runtime,
    )
    
    result = await orchestration_result.get(timeout=60)
    
    if isinstance(result, ResearchPerspectives):
        print("📊 Structured Research Results:")
        print(result.model_dump_json(indent=2))
    else:
        print(f"⚠️ Unexpected result type: {type(result)}")
        
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Structured Research: AI in Healthcare
# ==================================================
# 📊 Structured Research Results:
# {
#   "technology": {
#     "key_finding": "AI technologies across imaging, predictive analytics, genomics, drug discovery, NLP and remote monitoring have demonstrated superior accuracy and throughput compared with traditional methods, enabling earlier disease detection, personalized treatment and streamlined clinical operations.",
#     "supporting_evidence": "– Imaging: CNN models achieved AUC 0.94 on chest X-ray pathologies and reduced recall rates by 5% in mammography while maintaining >90% sensitivity (Nature Medicine 2020; JAMA 2022).\n– Predictive analytics: EHR-based ML models deliver AUCs of 0.75–0.85 for deterioration alerts and 0.82 for 30-day readmission prediction vs. 0.71 for standard scores (BMJ 2019; Epic Deterioration Index).  \n– Genomics: ML predicted immunotherapy response in melanoma with 78% accuracy vs. 55% for PD-L1 assays (Lancet Oncology 2021); DeepVariant improves variant calls by ~50%.  \n– Drug discovery: AI platforms designed a DDR1 inhibitor in 46 days (vs. 2–3 years industry avg.) and achieved 70% hit rates vs. ~1% in high-throughput screening (Insilico Medicine; Atomwise).  \n– NLP & RPA: Clinical NLP tools reached 95% F1-score for concept extraction; RPA cut prior-auth turnaround by 60% (Stanford; HIMSS Analytics 2022).  \n– Wearables: Smartwatch AFib detection PPV 0.84 (Apple Heart Study NEJM 2019); sleep-apnea screening at 92% accuracy with LSTM on wearable data (IEEE J-BHI 2023).",
#     "implications": "Deployment requires integration with existing IT systems (PACS/RIS/EHR), rigorous external validation, regulatory clearances (FDA/EMA), bias audits, data-governance frameworks, and multidisciplinary workflows to ensure safety, interoperability and clinician trust."
#   },
#   "market": {
#     "key_finding": "AI deployment in healthcare drives measurable cost savings, improved clinical throughput, reduced readmissions and enhanced patient engagement, creating new value propositions for providers, payers and life-sciences companies.",
#     "supporting_evidence": "– Diagnostic imaging: AI reduced false positives by 5–10%, matched or exceeded radiologist accuracy (94% vs. 88%) in lung nodule detection (JAMA Radiology 2020; Nature Medicine 2021).  \n– Predictive alerts: Sepsis AI systems cut ICU mortality by 20% and LOS by 1.5 days; readmission-prediction tools lowered 30-day rates by 12% (Critical Care Medicine 2019; HIMSS 2021).  \n– Drug R&D: AI can reduce discovery costs by 30–50% and accelerate timelines by 1–2 years (McKinsey).  \n– Virtual assistants: 65% of patients open to chatbots; adopters saw a 30% drop in no-shows and 20% higher medication adherence (KPMG; JMIR 2023).",
#     "implications": "Providers can boost throughput, lower diagnostic backlogs and unlock premium digital services. Payers benefit from reduced downstream costs and readmissions. Biopharma gains faster pipelines and smarter trial design. Success depends on evolving reimbursement models, liability frameworks, clear regulatory guidance and investment in change management to drive adoption."
#   }
# }

# %% [markdown]
# ## 3. Sequential Orchestration
#
# Sequential orchestration passes the output of one agent as input to the next, creating a pipeline.

# %%
def create_product_pipeline() -> list[Agent]:
    """Create a product development pipeline."""
    
    researcher = ChatCompletionAgent(
        name="ProductResearcher",
        instructions="You analyze product ideas and identify key features, target audience, and market opportunities.",
        service=chat_completion,
    )
    
    designer = ChatCompletionAgent(
        name="ProductDesigner",
        instructions="You create product concepts and specifications based on research insights.",
        service=chat_completion,
    )
    
    marketer = ChatCompletionAgent(
        name="ProductMarketer",
        instructions="You create marketing strategies and compelling messaging based on product designs.",
        service=chat_completion,
    )
    
    return [researcher, designer, marketer]

# Create sequential orchestration
product_pipeline = create_product_pipeline()
sequential_orchestration = SequentialOrchestration(
    members=product_pipeline,
    agent_response_callback=agent_response_callback,
)

print("✅ Sequential orchestration created!")
# Out:
# ✅ Sequential orchestration created!

# %%
# Test sequential orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Product Development Pipeline: Smart Home Security Device")
print("=" * 60)

try:
    orchestration_result = await sequential_orchestration.invoke(
        task="Develop a smart home security device that uses AI for threat detection.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get(timeout=120)
    print(f"\n**Final Marketing Strategy**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Product Development Pipeline: Smart Home Security Device
# ============================================================
# **ProductResearcher**
# Product Concept Summary
# A next-generation smart home security device that leverages on-device and cloud-assisted AI to detect, classify and respond to threats in real time—without overwhelming homeowners with false alarms. It combines advanced computer vision, audio analysis and sensor fusion in a compact, modular design that integrates with existing smart-home ecosystems.
#
# Key Features
# 1. AI-Driven Threat Detection
#   • Computer vision models trained to recognize people vs. animals, package deliveries, loitering, forced entry, weapons and aggressive behavior
#   • Acoustic analysis for glass-break, screaming, alarms or unusual sounds
#   • Multi-sensor fusion (PIR motion, radar, audio, vibration) to reduce false positives
#
# 2. Edge-Cloud Hybrid Processing
#   • On-device inference for privacy and low latency; critical alerts processed locally
#   • Optional cloud processing for advanced analytics (e.g. crowd behavior, license-plate reading)
#
# 3. Real-Time Alerts & Automated Response
#   • Push notifications with video or audio snippets to mobile app
#   • Two-way talkback and siren activation
#   • Automated lighting control or door-lock triggers via smart-home integration
#
# 4. Privacy & Security by Design
#   • End-to-end encryption for all video streams and stored clips
#   • Local processing of sensitive footage with user-controlled cloud backup
#   • Tamper detection and secure boot to prevent device hijacking
#
# 5. Modular, Easy Installation
#   • Indoor hub with optional battery-powered outdoor modules (cameras, motion sensors, glass‐break detectors)
#   • Wireless mesh networking for full-property coverage
#   • DIY mount-and-sync system or professional installation option
#
# 6. Seamless Smart-Home Integration
#   • Works with major voice assistants (Alexa, Google Assistant, Siri Shortcuts)
#   • Open APIs for custom automation (IFTTT, HomeKit, SmartThings)
#   • Compatibility with existing security panels and Z-Wave/Zigbee hubs
#
# 7. Scalable Service Plans
#   • Basic plan: on-device alerts, local storage (microSD)
#   • Standard plan: encrypted cloud storage (30 days), mobile alerts, 24/7 professional monitoring add-on
#   • Premium AI plan: advanced object classification, vicinity-wide risk scoring, forensic search tools
#
# Target Audience
# 1. Homeowners & Renters
#   • Tech-savvy families who want more intelligent, privacy-focused security
#   • Pet owners needing animal-aware motion detection
#
# 2. Small Business Operators
#   • Retail shops, cafés or home-offices requiring proactive threat alerts and remote monitoring
#
# 3. Elder & Child Care
#   • Multi-generational households monitoring elderly relatives or young children, with fall-or-cry detection
#
# 4. Security Service Providers
#   • Professional monitoring companies seeking AI-powered devices to reduce response times and false dispatch
#
# Market Opportunities
# 1. Rising Consumer Demand
#   • Global smart home security market growing at 10–12% CAGR; consumers want fewer false alarms and more actionable insights
#
# 2. Data Privacy Differentiation
#   • Positioning on-device AI and end-to-end encryption as a competitive edge over cloud-only solutions
#
# 3. Subscription-Based Recurring Revenue
#   • Tiered service plans open high-margin opportunities in cloud analytics, professional monitoring and feature add-ons
#
# 4. Channel Partnerships
#   • Alliances with ISPs, home-builders and alarm monitoring firms to bundle devices and services
#
# 5. International Expansion
#   • Regional gateway units with localized AI models (e.g., weapon detection regulations, license-plate formats)
#
# 6. Upsell & Cross-Sell
#   • Additional sensors (water leak, carbon monoxide) and smart-home peripherals (lighting, thermostats)
#
# Next Steps
# 1. Technical feasibility study on on-device AI acceleration (edge TPU, NPU chips)
# 2. UX prototyping for mobile app alert workflows
# 3. Security audit and privacy compliance roadmap (GDPR, CCPA)
# 4. Pilot program with 50–100 beta households to validate detection accuracy and user experience
# 5. Go-to-market strategy: direct-to-consumer e-commerce launch supported by targeted digital marketing, plus select retail partnerships
# --------------------------------------------------
# **ProductDesigner**
# Below is a more detailed Product Requirements Document (PRD) and technical specification set for the AI-powered smart home security system. You can share or adapt this to engineering, UX, security and marketing teams.
#
# 1. Product Overview
# • Name (working): SentinelAI Home Security Hub
# • Purpose: 24/7 real-time threat detection, alerting and automated response with minimal false alarms and maximum privacy.
# • Form factor: Small indoor hub (plug-in), plus optional battery-powered outdoor modules.
#
# 2. Key Use Cases
# • Front-door intrusion detection (person vs. package vs. animal)
# • Backyard or driveway monitoring (vehicle, loitering, license plate read)
# • Glass-break and forced-entry alert (audio + vibration analysis)
# • Elder-fall or child-cry detection inside home
# • Remote two-way voice and siren activation
# • Automated lighting or lock control when a threat is detected
#
# 3. Hardware Specification
# • Core compute module (indoor hub)
#   – Processor: quad-core ARM Cortex-A55 + integrated NPU/TPU accelerator (>2 TOPS)
#   – Memory: 2 GB DRAM; 8 GB local flash for firmware and models
#   – Storage: microSD slot (support up to 256 GB)
#   – Connectivity: Wi-Fi 802.11ac, Bluetooth LE 5.2, Zigbee 3.0, optional Ethernet
#   – Power: 12 V⎓1.5 A adapter; UPS backup via optional battery accessory
#   – Physical: 120×80×30 mm plastic enclosure, wall-mountable
# • Outdoor module (camera + multi-sensor)
#   – Camera: 2 MP color sensor, 1080p at 30 fps, 120° FOV, IR night vision
#   – Audio: MEMS microphone array for glass-break and scream detection
#   – Motion: PIR + FMCW radar for range and velocity
#   – Vibration: MEMS accelerometer for window-pane break detection
#   – Battery: 6,000 mAh rechargeable (6–12 month runtime typical)
#   – Wireless mesh: proprietary 900 MHz sub-GHz link to hub (up to 1 km LOS)
#   – Weather rating: IP65
#
# 4. Software & AI
# • On-Device Inference
#   – Person/animal/package/vehicle classifiers with confidence thresholds
#   – Acoustic event detection (glass, scream, alarm tone)
#   – Sensor fusion engine to correlate motion+sound before alert
# • Cloud-Assisted Processing (opt-in)
#   – High-accuracy license-plate reading, crowd-behavior analytics
#   – Historical forensics search and heat-map generation
# • Firmware & OS
#   – Embedded Linux with secure boot, signed firmware updates
#   – Containerized AI models managed by on-device orchestrator
# • Mobile & Web App
#   – Real-time push notifications with 5-second clip preview
#   – Live-view video stream (adaptive bitrate)
#   – Two-way audio and remote siren control
#   – Automation rules builder (if “person after 10 pm → turn on porch light”)
#   – Privacy zones and schedule management (suspend recording in nursery hours)
#
# 5. Security & Privacy
# • End-to-end encryption (AES-256 for data in transit; AES-128 for stored clips)
# • Local-first processing: sensitive frames never leave device unless user-enabled
# • Tamper detection: chassis-open sensor, mesh disconnect alarms
# • Identity & access management: OAuth2 for mobile app, 2FA optional
# • Compliance: GDPR, CCPA, UL 294, FCC Part 15
#
# 6. System Architecture
# • Hub orchestrates on-device AI and gateway to cloud
# • Outdoor modules form self-healing mesh backhaul to hub
# • Mobile/web clients connect via secure MQTT + HTTPS
# • Cloud services: device registry, model training pipeline, analytics dashboard
#
# 7. Performance Targets
# • Alert latency: <500 ms from event trigger to mobile push
# • False-alarm rate: <1 % in pilot field testing across 100 households
# • Uptime: 99.9 % availability for on-hub services; 99 % for cloud APIs
# • Video stream startup: <2 seconds to live feed on mobile
#
# 8. Manufacturing & Cost
# • Target BOM cost (hub + one outdoor): US $120 in volumes of 10k/mo
# • Retail price (D2C): hub kit US $249; each module US $99
# • Production timeline:
#   – Prototype ready: Q4 2024
#   – Pilot batch (100 units): Q1 2025
#   – Mass production: Q2 2025
#
# 9. Service Plans & Business Model
# • Basic (free): mobile alerts, local microSD storage
# • Standard (US $8.99/mo): 30-day encrypted cloud storage, professional monitoring add-on (US $5/mo)
# • Premium AI (US $14.99/mo): advanced analytics, forensic search, license-plate logs
# • One-time hardware revenue + recurring subscription margin
#
# 10. Next Steps
# • Finalize hardware feasibility study for NPU module and mesh radio
# • Build end-to-end prototype (hub + 3 modules) for lab accuracy tests
# • Develop UX flows and UI mockups for mobile alarm management
# • Conduct security audit with third-party pen-test vendor
# • Recruit beta families in 3 markets (urban, suburban, rural) for real-world validation
# • Prepare go-to-market partnerships with ISP/security-monitoring firms and select retailers
#
# This PRD can be handed off to your hardware, firmware, cloud, UX and security teams as a foundation for detailed design sprints and development roadmaps.
# --------------------------------------------------
# **ProductMarketer**
# Below is a concise marketing strategy plus a set of core messages, positioning statements and sample copy you can adapt for your website, ads, emails and partner decks.
#
# 1. Positioning & Value Propositions
# • “SentinelAI Home Security Hub” is the first privacy-first, AI-powered DIY system that delivers professional-grade protection without constant monitoring fees or false alarms.
# • Key benefits:
#   – Hyper-accurate threat detection (people, packages, vehicles, glass-break) with <1% false alarms
#   – On-device AI keeps sensitive video/audio local unless you choose to share
#   – Modular, wireless mesh design you install yourself—no electrician or monthly contract required
#   – Integrated automation (lights, locks, siren) for real-time response
#
# 2. Target Audiences
# • Suburban homeowners with kids, pets or elderly relatives who want peace of mind
# • Urban renters and condo owners seeking a no-drill, bolt-and-go security upgrade
# • Tech-savvy DIYers who demand privacy and control but don’t want to pay professional monitoring fees
# • ISPs, security integrators and telco partners looking to bundle a low-cost, high-margin hardware+subscription service
#
# 3. Go-to-Market Channels
# • Direct-to-Consumer Website (D2C) with interactive “build your kit” configurator
# • Amazon and leading retail partners for impulse purchase modules
# • Co-marketing bundles with ISPs and smart-home platforms (e.g., Alexa, Google Home)
# • Security-focused online publications, podcasts and YouTube influencers for product reviews
# • Paid search & social (Facebook, Instagram): hyper-targeted ads to lookalike homeowner audiences
#
# 4. Tiered Service Plans (Messaging Focus)
# • Basic (Free): local storage, AI-alerts, DIY install = “Starter security at zero cost.”
# • Standard ($8.99/mo): 30-day encrypted cloud video + door-to-door pro monitoring add-on = “Complete, worry-free coverage.”
# • Premium AI ($14.99/mo): advanced analytics (forensics, license plates, heat-maps) = “Insights and evidence, on demand.”
#
# 5. Core Messaging Pillars
# • “Smarter Alerts, Not More Noise” – AI sensor fusion stops cats, drones and squirrels from waking you.
# • “Your Data, Your Rules” – opt in to cloud services only when you want; sensitive footage never leaves your home by default.
# • “Plug. Pair. Protect.” – 5-minute install of hub and wireless modules; no drilling, no monthly contracts.
# • “Self-Healing Mesh” – modules speak directly to each other and the hub up to 1 km away—no dead zones.
#
# 6. Taglines & Headlines
# • “SentinelAI: Home Security That Thinks for Itself”
# • “Stop False Alarms. Start Smart Security.”
# • “Protect What Matters with AI-Powered Precision”
# • “Your Home’s Guardian—Watching 24/7, Silently, Privately.”
#
# 7. Sample Website Hero Section
# Headline: Protect Every Corner of Your Home—Silently, Securely, Smarter
# Subhead: SentinelAI uses on-device intelligence to tell people from packages, cars from critters, glass breaks from gusts of wind. No false alarms, no hidden fees.
# Primary CTA: Configure Your Kit   Secondary CTA: Watch Demo
#
# 8. Sample Ad Copy
# • Facebook Carousel Ad (three panels)
#   1) “Tired of false alarms keeping you up all night?”
#   2) “SentinelAI uses AI + sensor fusion for <1% false-alarm rate.”
#   3) “DIY install in minutes. Protect your home today—starting at $249.”
#
# • Google Search Ad
#   Headline 1: AI Home Security Hub – No Contracts
#   Headline 2: Zero False Alarms • DIY Install
#   Description: Stop unwanted alerts. 24/7 on-device AI. Free basic plan + modular add-ons.
#
# 9. Email Drip Campaign Outline
# • Email 1 (Awareness): “Meet SentinelAI—The New Standard in DIY Home Security” (focus on pain of false alarms)
# • Email 2 (Education): “How On-Device AI Keeps Your Home Safer & Your Privacy Intact” (technology deep-dive)
# • Email 3 (Offer): “Build Your SentinelAI Kit + Get 10% Off Your First Module” (time-limited promo)
# • Email 4 (Re-engage): “3 Real Stories: How SentinelAI Stopped Break-Ins & Naptime Nuisances” (customer testimonials)
#
# 10. Partner & Channel-Sales Messaging
# • Security Integrators: “Extend your service portfolio with a low-cost, high-margin DIY-friendly AI security ecosystem.”
# • ISPs/Telcos: “Differentiate your fiber/broadband bundles—offer customers home security hardware plus managed monitoring plans.”
# • Retail Buyers: “Fast-moving consumer electronics at a $99–$249 price point, backed by a recurring revenue subscription model.”
#
# Next Steps
# • Finalize brand identity (logo, color palette, tone of voice) around “smart, trustworthy, private.”
# • Produce hero video showing day/night use cases, install simplicity and privacy features.
# • Build landing-page A/B tests for messaging headlines and service-plan layouts.
# • Line up influential home-security bloggers for beta reviews and social amplification.
# • Coordinate paid-media launch in tandem with PR announcement (focused on false-alarm reduction stats).
# --------------------------------------------------
#
# **Final Marketing Strategy**
# Below is a concise marketing strategy plus a set of core messages, positioning statements and sample copy you can adapt for your website, ads, emails and partner decks.
#
# 1. Positioning & Value Propositions
# • “SentinelAI Home Security Hub” is the first privacy-first, AI-powered DIY system that delivers professional-grade protection without constant monitoring fees or false alarms.
# • Key benefits:
#   – Hyper-accurate threat detection (people, packages, vehicles, glass-break) with <1% false alarms
#   – On-device AI keeps sensitive video/audio local unless you choose to share
#   – Modular, wireless mesh design you install yourself—no electrician or monthly contract required
#   – Integrated automation (lights, locks, siren) for real-time response
#
# 2. Target Audiences
# • Suburban homeowners with kids, pets or elderly relatives who want peace of mind
# • Urban renters and condo owners seeking a no-drill, bolt-and-go security upgrade
# • Tech-savvy DIYers who demand privacy and control but don’t want to pay professional monitoring fees
# • ISPs, security integrators and telco partners looking to bundle a low-cost, high-margin hardware+subscription service
#
# 3. Go-to-Market Channels
# • Direct-to-Consumer Website (D2C) with interactive “build your kit” configurator
# • Amazon and leading retail partners for impulse purchase modules
# • Co-marketing bundles with ISPs and smart-home platforms (e.g., Alexa, Google Home)
# • Security-focused online publications, podcasts and YouTube influencers for product reviews
# • Paid search & social (Facebook, Instagram): hyper-targeted ads to lookalike homeowner audiences
#
# 4. Tiered Service Plans (Messaging Focus)
# • Basic (Free): local storage, AI-alerts, DIY install = “Starter security at zero cost.”
# • Standard ($8.99/mo): 30-day encrypted cloud video + door-to-door pro monitoring add-on = “Complete, worry-free coverage.”
# • Premium AI ($14.99/mo): advanced analytics (forensics, license plates, heat-maps) = “Insights and evidence, on demand.”
#
# 5. Core Messaging Pillars
# • “Smarter Alerts, Not More Noise” – AI sensor fusion stops cats, drones and squirrels from waking you.
# • “Your Data, Your Rules” – opt in to cloud services only when you want; sensitive footage never leaves your home by default.
# • “Plug. Pair. Protect.” – 5-minute install of hub and wireless modules; no drilling, no monthly contracts.
# • “Self-Healing Mesh” – modules speak directly to each other and the hub up to 1 km away—no dead zones.
#
# 6. Taglines & Headlines
# • “SentinelAI: Home Security That Thinks for Itself”
# • “Stop False Alarms. Start Smart Security.”
# • “Protect What Matters with AI-Powered Precision”
# • “Your Home’s Guardian—Watching 24/7, Silently, Privately.”
#
# 7. Sample Website Hero Section
# Headline: Protect Every Corner of Your Home—Silently, Securely, Smarter
# Subhead: SentinelAI uses on-device intelligence to tell people from packages, cars from critters, glass breaks from gusts of wind. No false alarms, no hidden fees.
# Primary CTA: Configure Your Kit   Secondary CTA: Watch Demo
#
# 8. Sample Ad Copy
# • Facebook Carousel Ad (three panels)
#   1) “Tired of false alarms keeping you up all night?”
#   2) “SentinelAI uses AI + sensor fusion for <1% false-alarm rate.”
#   3) “DIY install in minutes. Protect your home today—starting at $249.”
#
# • Google Search Ad
#   Headline 1: AI Home Security Hub – No Contracts
#   Headline 2: Zero False Alarms • DIY Install
#   Description: Stop unwanted alerts. 24/7 on-device AI. Free basic plan + modular add-ons.
#
# 9. Email Drip Campaign Outline
# • Email 1 (Awareness): “Meet SentinelAI—The New Standard in DIY Home Security” (focus on pain of false alarms)
# • Email 2 (Education): “How On-Device AI Keeps Your Home Safer & Your Privacy Intact” (technology deep-dive)
# • Email 3 (Offer): “Build Your SentinelAI Kit + Get 10% Off Your First Module” (time-limited promo)
# • Email 4 (Re-engage): “3 Real Stories: How SentinelAI Stopped Break-Ins & Naptime Nuisances” (customer testimonials)
#
# 10. Partner & Channel-Sales Messaging
# • Security Integrators: “Extend your service portfolio with a low-cost, high-margin DIY-friendly AI security ecosystem.”
# • ISPs/Telcos: “Differentiate your fiber/broadband bundles—offer customers home security hardware plus managed monitoring plans.”
# • Retail Buyers: “Fast-moving consumer electronics at a $99–$249 price point, backed by a recurring revenue subscription model.”
#
# Next Steps
# • Finalize brand identity (logo, color palette, tone of voice) around “smart, trustworthy, private.”
# • Produce hero video showing day/night use cases, install simplicity and privacy features.
# • Build landing-page A/B tests for messaging headlines and service-plan layouts.
# • Line up influential home-security bloggers for beta reviews and social amplification.
# • Coordinate paid-media launch in tandem with PR announcement (focused on false-alarm reduction stats).

# %% [markdown]
# ### 3.1 Streaming and intermediate results with Orchestration
#
# Lets looks at how you can use streaming and observe intermediate results with the sequential pattern. This will work for other orchestration patterns too.

# %%
# Global variable to track streaming state
is_new_message = True

def streaming_agent_response_callback(message: StreamingChatMessageContent, is_final: bool) -> None:
    """Handle streaming responses from agents."""
    global is_new_message
    
    if is_new_message:
        print(f"\n**{message.name}**")
        is_new_message = False
        
    print(message.content, end="", flush=True)
    
    if is_final:
        print("\n" + "-" * 50)
        is_new_message = True

def agent_response_callback(message: ChatMessageContent) -> None:
    """Handle support agent responses."""
    
    # Show function calls
    for item in message.items:
        if isinstance(item, FunctionCallContent):
            print(f"  📞 Calling: {item.name}({item.arguments})")
        elif isinstance(item, FunctionResultContent):
            print(f"  📋 Result: {item.result}")


class AnalysisPlugin:
    """Plugin that provides analysis capabilities."""
    
    @kernel_function(description="Analyze a topic and provide insights.")
    def analyze_topic(self, topic: Annotated[str, "The topic to analyze"]) -> str:
        # Simulate analysis processing
        return f"Analysis of '{topic}': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility."
    
    @kernel_function(description="Generate recommendations based on analysis.")
    def generate_recommendations(self, analysis: Annotated[str, "The analysis to base recommendations on"]) -> str:
        return "Recommendations: 1) Conduct further research, 2) Develop a prototype, 3) Test with users, 4) Iterate based on feedback."

analysis_agent = ChatCompletionAgent(
    service=chat_completion,
    name="AnalysisExpert",
    instructions="You are an expert analyst. Use your tools to provide thorough analysis and recommendations.",
    plugins=[AnalysisPlugin()]
)

summarizer_agent = ChatCompletionAgent(
    service=chat_completion,
    name="Summarizer",
    instructions="You summarize results in no more than 100 words.",
)

# Create streaming sequential orchestration
streaming_sequential = SequentialOrchestration(
    members=[analysis_agent, summarizer_agent], ## Resusing reasoning agent for demonstration purposes.
    streaming_agent_response_callback=streaming_agent_response_callback,
    agent_response_callback=agent_response_callback
)

print("✅ Streaming sequential orchestration created!")
# Out:
# ✅ Streaming sequential orchestration created!

# %%
# Test streaming sequential orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Streaming Product Pipeline: Fitness Wearable")
print("=" * 60)

try:
    orchestration_result = await streaming_sequential.invoke(
        task="Create a fitness wearable that tracks mental wellness alongside physical health.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get(timeout=120)
    print(f"\n\n**Final Pipeline Result**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Streaming Product Pipeline: Fitness Wearable
# ============================================================
#   📞 Calling: AnalysisPlugin-analyze_topic({"topic":"fitness wearable that tracks mental wellness alongside physical health"})
#
# **AnalysisExpert**
#
# --------------------------------------------------
#   📋 Result: Analysis of 'fitness wearable that tracks mental wellness alongside physical health': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility.
#
# **AnalysisExpert**
#
# --------------------------------------------------
#
# **AnalysisExpert**
#   📞 Calling: AnalysisPlugin-generate_recommendations({"analysis":"Analysis of 'fitness wearable that tracks mental wellness alongside physical health':\n\n1. Market Trends and User Needs:\n   - Rising Demand for Holistic Health Solutions: Consumers increasingly seek devices that offer both physical and mental health insights in one package.\n   - Mental Wellness Awareness Growth: Post-pandemic, mental health tracking (stress, mood, sleep quality) has become a significant priority.\n   - Key User Segments: Wellness enthusiasts, mental health advocates, corporate wellness programs, athletes seeking recovery insights.\n\n2. Core Features and Metrics:\n   - Physical Health Tracking: Heart rate, heart rate variability (HRV), steps, calories burned, sleep stages, workout detection.\n   - Mental Wellness Tracking: Real-time stress monitoring (via HRV), mood logging (user input), sleep quality analysis, breathing rate, galvanic skin response (GSR), AI-driven mental state inference, guided breathing or mindfulness prompts.\n   - Contextual Data Correlation: Linking physical exertion, sleep patterns, and daily routine with mood/stress levels to provide actionable insights.\n\n3. Technical Feasibility and Design Considerations:\n   - Sensor Suite Integration: Incorporate PPG sensors for HR and HRV, GSR sensor for stress, accelerometer/gyroscope for activity detection, skin temperature sensor.\n   - Battery and Form Factor: Optimizing power consumption for multiple sensors; lightweight, comfortable design that supports 24/7 wear; swappable bands.\n   - Data Processing and AI: On-device preliminary processing to reduce latency and maintain privacy; cloud-based AI models to analyze long-term patterns; edge computing for real-time stress alerts.\n   - Privacy and Security: End-to-end encryption, GDPR and HIPAA compliance; user-controlled data sharing permissions.\n\n4. User Experience (UX):\n   - Intuitive Dashboard: Unified app dashboard showing physical and mental health metrics in easy-to-digest formats (graphs, scores).\n   - Personalized Insights: Notifications and recommendations tailored to individual patterns (e.g., rest days when stress/HRV indicate elevated fatigue).\n   - Engagement Features: Gamification, community challenges, virtual coaching, mindfulness sessions.\n\n5. Competitive Landscape:\n   - Existing Players: Fitbit, Apple Watch, Garmin, Oura Ring. Most focus primarily on physical metrics; some also track sleep/stress.\n   - Differentiation Opportunity: Depth in mental wellness analytics, more precise stress detection via multi-sensor fusion, actionable mindfulness interventions, robust AI-driven personal coach.\n\n6. Business and Go-to-Market Strategy:\n   - Pricing Model: Device purchase plus subscription tier for advanced AI insights and guided programs.\n   - Partnerships: Collaborate with mental health professionals, meditation apps (e.g., Calm, Headspace), corporate wellness platforms.\n   - Distribution Channels: Direct-to-consumer online, partnerships with gyms, healthcare providers, corporate wellness.\n\n7. Regulatory and Ethical Considerations:\n   - Medical Device Classification: Determine if features require FDA or CE approval (e.g., stress-related health interventions).\n   - Ethical Use of Data: Avoid over-reliance on AI for mental health diagnoses; clearly communicate purpose and limitations.\n"})
#
# --------------------------------------------------
#   📋 Result: Recommendations: 1) Conduct further research, 2) Develop a prototype, 3) Test with users, 4) Iterate based on feedback.
#
# **AnalysisExpert**
#
# --------------------------------------------------
#
# **AnalysisExpert**
# Below are strategic recommendations for developing a fitness wearable that tracks mental wellness alongside physical health, based on the detailed analysis:
#
# 1. Deep-Dive Research & Validation
#    • User Interviews & Surveys: Engage wellness enthusiasts, mental-health advocates and corporate wellness coordinators to validate feature priorities.
#    • Sensor Accuracy Studies: Partner with research labs to verify reliability of PPG/HRV, GSR and skin-temperature readings for stress detection.
#
# 2. Prototype & Technical Development
#    • Sensor Suite Integration: Build an initial hardware prototype integrating PPG, GSR, accelerometer and skin temperature sensors.
#    • On-Device Processing: Implement lightweight algorithms for real-time HRV/stress detection. Use edge computing to trigger immediate mindfulness prompts.
#    • Cloud AI Pipeline: Design cloud infrastructure for long-term pattern analysis and personalized insights, ensuring privacy by encrypting data end to end.
#
# 3. User Experience & Feature Rollout
#    • App Dashboard: Develop a unified mobile app showing physical metrics (heart rate, steps, sleep) alongside mental-wellness scores and mood logs.
#    • Guided Interventions: Integrate short breathing exercises and guided mindfulness sessions triggered when stress levels spike.
#    • Personalization Engine: Build an AI module that suggests rest days, guided workouts or mindfulness breaks based on combined physical + mental data.
#
# 4. Testing & Iteration
#    • Pilot Studies: Run a closed beta with target users. Collect quantitative data (sensor accuracy, engagement rates) and qualitative feedback (usability, perceived value).
#    • Data-Driven Refinement: Tune detection thresholds, improve UI flows, and enhance recommendation relevance based on pilot results.
#
# 5. Go-to-Market & Partnerships
#    • Freemium Model: Offer basic tracking for free; tiered subscription unlocks deep-dive analytics, mental-wellness programs and guided coaching.
#    • Strategic Alliances: Partner with mental-health platforms (e.g., Headspace/Calm), wellness clinics and corporate wellness providers to broaden reach.
#    • Regulatory Compliance: Evaluate medical-device classifications to ensure FDA/CE approvals if marketing stress interventions as therapeutic.
#
# 6. Privacy, Ethics & Long-Term Roadmap
#    • Data Governance: Implement user-controlled sharing, anonymized analytics, and compliance with GDPR/HIPAA.
#    • Ethical Boundaries: Clearly communicate that the device offers insights—not clinical diagnoses—and encourage users to consult professionals for serious concerns.
#    • Future Enhancements: Explore integration of voice-based sentiment analysis, advanced sleep-stage tracking, and community-based challenges for holistic well-being.
#
# By following these steps—grounded in user research, robust prototyping, and a strong go-to-market strategy—you can deliver a differentiated, impactful wearable that truly bridges physical fitness and mental wellness.
# --------------------------------------------------
#
# **Summarizer**
# 1. Research: conduct user interviews, validate sensors for stress detection.
# 2. Develop prototype with PPG, GSR, accelerometer, skin-temperature; implement on-device stress detection and cloud analytics.
# 3. UX: unified app dashboard for physical/mental metrics, guided mindfulness, personalized recommendations.
# 4. Test: closed beta, iterate on sensor thresholds and UI.
# 5. GTM: freemium model, partnerships with mental-health platforms, ensure regulatory compliance.
# 6. Privacy/Ethics: encrypt data, user-controlled sharing, clear non-diagnostic messaging.
# Future roadmap: voice sentiment analysis, advanced sleep tracking, community challenges.
# --------------------------------------------------
#
#
# **Final Pipeline Result**
# 1. Research: conduct user interviews, validate sensors for stress detection.
# 2. Develop prototype with PPG, GSR, accelerometer, skin-temperature; implement on-device stress detection and cloud analytics.
# 3. UX: unified app dashboard for physical/mental metrics, guided mindfulness, personalized recommendations.
# 4. Test: closed beta, iterate on sensor thresholds and UI.
# 5. GTM: freemium model, partnerships with mental-health platforms, ensure regulatory compliance.
# 6. Privacy/Ethics: encrypt data, user-controlled sharing, clear non-diagnostic messaging.
# Future roadmap: voice sentiment analysis, advanced sleep tracking, community challenges.

# %% [markdown]
# ## 4. LLM-Based Group Chat Manager
#
# For more sophisticated group interactions, you can create LLM-based group chat managers that use AI to intelligently decide who speaks next based on conversation context and participant expertise.

# %%
class LLMBasedGroupChatManager(GroupChatManager):
    """LLM-based group chat manager that uses AI to decide who speaks next.
    
    This manager uses the LLM to intelligently select the next speaker based on
    conversation context and participant expertise. Key features:
    
    - Uses AI to determine when the discussion should end
    - Selects speakers based on conversation context and agent descriptions
    - Provides reasoning for each selection and termination decision
    - Generates intelligent summaries of the discussion
    """

    service: ChatCompletionClientBase
    topic: str

    termination_prompt: str = (
        "You are mediator that guides a discussion on the topic of '{{$topic}}'. "
        "You need to determine if the discussion has reached a conclusion. "
        "If you would like to end the discussion, please respond with True. Otherwise, respond with False."
    )

    selection_prompt: str = (
        "You are mediator that guides a discussion on the topic of '{{$topic}}'. "
        "You need to select the next participant to speak. "
        "Here are the names and descriptions of the participants: "
        "{{$participants}}\n"
        "Please respond with only the name of the participant you would like to select."
    )

    result_filter_prompt: str = (
        "You are mediator that guides a discussion on the topic of '{{$topic}}'. "
        "You have just concluded the discussion. "
        "Please summarize the discussion and provide a closing statement."
    )

    def __init__(self, topic: str, service: ChatCompletionClientBase, **kwargs) -> None:
        """Initialize the group chat manager."""
        super().__init__(topic=topic, service=service, **kwargs)

    async def _render_prompt(self, prompt: str, arguments: KernelArguments) -> str:
        """Helper to render a prompt with arguments."""
        prompt_template_config = PromptTemplateConfig(template=prompt)
        prompt_template = KernelPromptTemplate(prompt_template_config=prompt_template_config)
        return await prompt_template.render(Kernel(), arguments=arguments)

    @override
    async def should_request_user_input(self, chat_history: ChatHistory) -> BooleanResult:
        """Provide concrete implementation for determining if user input is needed.

        The manager will check if input from human is needed after each agent message.
        """
        return BooleanResult(
            result=False,
            reason="This group chat manager does not require user input.",
        )

    @override
    async def should_terminate(self, chat_history: ChatHistory) -> BooleanResult:
        """Provide concrete implementation for determining if the discussion should end.

        The manager will check if the conversation should be terminated after each agent message
        or human input (if applicable).
        """
        should_terminate = await super().should_terminate(chat_history)
        if should_terminate.result:
            return should_terminate

        chat_history.messages.insert(
            0,
            ChatMessageContent(
                role=AuthorRole.SYSTEM,
                content=await self._render_prompt(
                    self.termination_prompt,
                    KernelArguments(topic=self.topic),
                ),
            ),
        )
        chat_history.add_message(
            ChatMessageContent(role=AuthorRole.USER, content="Determine if the discussion should end."),
        )

        response = await self.service.get_chat_message_content(
            chat_history,
            settings=PromptExecutionSettings(response_format=BooleanResult),
        )

        termination_with_reason = BooleanResult.model_validate_json(response.content)

        print("*********************")
        print(f"🤖 LLM Decision - Should terminate: {termination_with_reason.result}")
        print(f"📝 Reason: {termination_with_reason.reason}")
        print("*********************")

        return termination_with_reason

    @override
    async def select_next_agent(
        self,
        chat_history: ChatHistory,
        participant_descriptions: dict[str, str],
    ) -> StringResult:
        """Provide concrete implementation for selecting the next agent to speak.

        The manager will select the next agent to speak after each agent message
        or human input (if applicable) if the conversation is not terminated.
        """
        chat_history.messages.insert(
            0,
            ChatMessageContent(
                role=AuthorRole.SYSTEM,
                content=await self._render_prompt(
                    self.selection_prompt,
                    KernelArguments(
                        topic=self.topic,
                        participants="\n".join([f"{k}: {v}" for k, v in participant_descriptions.items()]),
                    ),
                ),
            ),
        )
        chat_history.add_message(
            ChatMessageContent(role=AuthorRole.USER, content="Now select the next participant to speak."),
        )

        response = await self.service.get_chat_message_content(
            chat_history,
            settings=PromptExecutionSettings(response_format=StringResult),
        )

        participant_name_with_reason = StringResult.model_validate_json(response.content)

        print("*********************")
        print(f"🤖 LLM Selection - Next participant: {participant_name_with_reason.result}")
        print(f"📝 Reason: {participant_name_with_reason.reason}")
        print("*********************")

        if participant_name_with_reason.result in participant_descriptions:
            return participant_name_with_reason

        raise RuntimeError(f"Unknown participant selected: {response.content}.")

    @override
    async def filter_results(
        self,
        chat_history: ChatHistory,
    ) -> MessageResult:
        """Provide concrete implementation for filtering the results of the discussion.

        The manager will filter the results of the conversation after the conversation is terminated.
        """
        if not chat_history.messages:
            raise RuntimeError("No messages in the chat history.")

        chat_history.messages.insert(
            0,
            ChatMessageContent(
                role=AuthorRole.SYSTEM,
                content=await self._render_prompt(
                    self.result_filter_prompt,
                    KernelArguments(topic=self.topic),
                ),
            ),
        )
        chat_history.add_message(
            ChatMessageContent(role=AuthorRole.USER, content="Please summarize the discussion."),
        )

        response = await self.service.get_chat_message_content(
            chat_history,
            settings=PromptExecutionSettings(response_format=StringResult),
        )
        string_with_reason = StringResult.model_validate_json(response.content)

        return MessageResult(
            result=ChatMessageContent(role=AuthorRole.ASSISTANT, content=string_with_reason.result),
            reason=string_with_reason.reason,
        )

print("✅ LLM-based Group Chat Manager created!")
# Out:
# ✅ LLM-based Group Chat Manager created!

# %%
# Create debate agents with rich descriptions for LLM selection
def create_debate_agents() -> list[Agent]:
    """Create agents for a debate scenario."""
    
    optimist = ChatCompletionAgent(
        name="TechOptimist",
        description="A technology optimist who believes in AI's positive potential and focuses on benefits, opportunities, and solutions.",
        instructions="You believe AI will greatly benefit humanity. Present positive arguments with specific examples and address concerns constructively.",
        service=chat_completion,
    )
    
    skeptic = ChatCompletionAgent(
        name="TechSkeptic", 
        description="A technology skeptic who is concerned about AI risks and challenges, focusing on potential problems and ethical concerns.",
        instructions="You are concerned about AI risks and challenges. Present thoughtful counterarguments and highlight potential dangers while being respectful.",
        service=chat_completion,
    )
    
    return [optimist, skeptic]

# Create LLM-based group chat
debate_agents = create_debate_agents()
llm_group_chat = GroupChatOrchestration(
    members=debate_agents,
    manager=LLMBasedGroupChatManager(
        topic="The Future of AI in Society",
        service=chat_completion,
        max_rounds=8,
    ),
    agent_response_callback=agent_response_callback,
)

print("✅ LLM-based group chat for debate created!")
# Out:
# ✅ LLM-based group chat for debate created!

# %%
# Test LLM-based group chat
runtime = InProcessRuntime()
runtime.start()

print("🎯 AI Debate: The Future of AI in Society")
print("🤖 LLM Manager will intelligently decide who speaks next based on context")
print("=" * 60)

try:
    orchestration_result = await llm_group_chat.invoke(
        task="Discuss the benefits and risks of AI integration in society. Consider both opportunities and challenges.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get()
    print(f"\n**LLM-Mediated Debate Summary**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 AI Debate: The Future of AI in Society
# 🤖 LLM Manager will intelligently decide who speaks next based on context
# ============================================================
# *********************
# 🤖 LLM Decision - Should terminate: False
# 📝 Reason: The discussion has not yet covered the benefits and risks of AI integration; further exploration is needed.
# *********************
# *********************
# 🤖 LLM Selection - Next participant: TechOptimist
# 📝 Reason: Starting with the optimistic view will highlight the potential benefits and opportunities of AI integration in society.
# *********************
# **TechOptimist**
# Below is a balanced overview of how AI can be integrated into society, highlighting both its promise and the challenges we must address.
#
# Benefits and Opportunities
# • Healthcare improvements
#   – Early diagnosis: AI algorithms can spot patterns in medical imaging (e.g., detecting tumors in X-rays or MRIs) faster than the human eye.
#   – Personalized treatment: Machine-learning models analyze genetic and lifestyle data to tailor therapies for cancer, diabetes and other conditions.
#   – Opera... [truncated]
# --------------------------------------------------
# *********************
# 🤖 LLM Decision - Should terminate: True
# 📝 Reason: The discussion has covered benefits, risks, mitigation strategies, and provided a concluding summary.
# *********************
#
# **LLM-Mediated Debate Summary**
# Summary: The discussion covered AI’s transformative benefits—improved diagnostics and personalized care in healthcare; automation and supply-chain optimization in industry; adaptive learning and accessibility in education; and enhanced climate modeling, energy management and wildlife protection for the environment. We also explored risks such as workforce displacement, algorithmic bias, privacy and surveillance concerns, security vulnerabilities, and ethical challenges around accountability. Proposed mitigation strategies included the adoption of ethical frameworks, risk-based regulation, investments in explainable AI, comprehensive workforce retraining programs, and inclusive public–private governance.
#
# Closing statement: By proactively addressing these risks through collaboration, transparency and regulation, we can harness AI’s potential to drive innovation and societal good while safeguarding individual rights and equity.

# %% [markdown]
# ## 5. Handoff Orchestration
#
# Handoff orchestration allows agents to transfer conversations to specialized agents based on the context.

# %%
# Create specialized support plugins
class TechnicalSupportPlugin:
    """Plugin for technical support tasks."""
    
    @kernel_function(description="Diagnose technical issues.")
    def diagnose_issue(self, issue: Annotated[str, "Description of the technical issue"]) -> str:
        return f"Diagnosis for '{issue}': This appears to be a common connectivity issue. Try restarting your device and checking your network connection."
    
    @kernel_function(description="Provide troubleshooting steps.")
    def troubleshoot(self, diagnosis: Annotated[str, "The diagnosis result"]) -> str:
        return "Troubleshooting steps: 1) Restart device, 2) Check network, 3) Update software, 4) Contact support if issue persists."

class BillingSupportPlugin:
    """Plugin for billing support tasks."""
    
    @kernel_function(description="Check billing information.")
    def check_billing(self, account_id: Annotated[str, "Account ID"]) -> str:
        return f"Billing info for account {account_id}: Current balance: $45.99, Next payment due: 2024-02-15"
    
    @kernel_function(description="Process payment.")
    def process_payment(self, amount: Annotated[str, "Payment amount"]) -> str:
        return f"Payment of {amount} processed successfully. Thank you!"

print("✅ Support plugins created!")
# Out:
# ✅ Support plugins created!

# %%
# Create specialized support agents
triage_agent = ChatCompletionAgent(
    name="SupportTriage",
    description="A triage agent that routes customers to appropriate specialists.",
    instructions="You help customers by understanding their needs and routing them to the right specialist. Be friendly and efficient.",
    service=chat_completion,
)

tech_support_agent = ChatCompletionAgent(
    name="TechSupport",
    description="A technical support specialist.",
    instructions="You provide technical support and troubleshooting. Use your tools to diagnose and solve problems.",
    service=chat_completion,
    plugins=[TechnicalSupportPlugin()],
)

billing_support_agent = ChatCompletionAgent(
    name="BillingSupport",
    description="A billing support specialist.",
    instructions="You handle billing questions and payment processing. Use your tools to help with account issues.",
    service=chat_completion,
    plugins=[BillingSupportPlugin()],
)

print("✅ Support agents created!")
# Out:
# ✅ Support agents created!

# %%
# Define handoff relationships
handoffs = (
    OrchestrationHandoffs()
    .add_many(
        source_agent=triage_agent.name,
        target_agents={
            tech_support_agent.name: "Transfer to this agent for technical issues and troubleshooting",
            billing_support_agent.name: "Transfer to this agent for billing, payment, and account issues",
        },
    )
    .add(
        source_agent=tech_support_agent.name,
        target_agent=triage_agent.name,
        description="Transfer back to triage if the issue is not technical",
    )
    .add(
        source_agent=billing_support_agent.name,
        target_agent=triage_agent.name,
        description="Transfer back to triage if the issue is not billing-related",
    )
)

print("✅ Handoff relationships defined!")
# Out:
# ✅ Handoff relationships defined!

# %%
# Create handoff orchestration
def support_response_callback(message: ChatMessageContent) -> None:
    """Handle support agent responses."""
    print(f"**{message.name}**: {message.content}")
    
    # Show function calls
    for item in message.items:
        if isinstance(item, FunctionCallContent):
            print(f"  📞 Calling: {item.name}({item.arguments})")
        elif isinstance(item, FunctionResultContent):
            print(f"  📋 Result: {item.result}")
    print("-" * 50)

handoff_orchestration = HandoffOrchestration(
    members=[
        triage_agent,
        tech_support_agent,
        billing_support_agent,
    ],
    handoffs=handoffs,
    agent_response_callback=support_response_callback,
)

print("✅ Handoff orchestration created!")
# Out:
# ✅ Handoff orchestration created!

# %%
# Test handoff orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Customer Support Scenario: Technical Issue")
print("=" * 60)

try:
    orchestration_result = await handoff_orchestration.invoke(
        task="Hi, I'm having trouble connecting to the internet. My device keeps disconnecting.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get()
    print(f"\n**Support Resolution**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Customer Support Scenario: Technical Issue
# ============================================================
# **SupportTriage**:
#   📞 Calling: Handoff-transfer_to_TechSupport({})
# --------------------------------------------------
# **SupportTriage**:
#   📋 Result: None
# --------------------------------------------------
# **SupportTriage**:
# --------------------------------------------------
# **TechSupport**:
#   📞 Calling: TechnicalSupportPlugin-diagnose_issue({"issue":"User's device keeps disconnecting from the internet."})
# --------------------------------------------------
# **TechSupport**:
#   📋 Result: Diagnosis for 'User's device keeps disconnecting from the internet.': This appears to be a common connectivity issue. Try restarting your device and checking your network connection.
# --------------------------------------------------
# **TechSupport**:
#   📞 Calling: TechnicalSupportPlugin-troubleshoot({"diagnosis":"Common connectivity issue. Try restarting your device and checking your network connection."})
# --------------------------------------------------
# **TechSupport**:
#   📋 Result: Troubleshooting steps: 1) Restart device, 2) Check network, 3) Update software, 4) Contact support if issue persists.
# --------------------------------------------------
# **TechSupport**: Here are some steps you can take to address the disconnects:
#
# 1) Restart Your Device
#    - Fully power off your computer/phone/router, wait 30 seconds, then power back on.
#
# 2) Check Your Network
#    - Ensure your Wi-Fi is turned on.
#    - Move closer to the router or remove physical obstructions.
#    - If on Ethernet, verify the cable is firmly plugged in.
#
# 3) Update Software/Firmware
#    - On your device: check for and install any OS or driver updates.
#    - On your router: log into its admin interface and update the firmware if available.
#
# 4) Monitor Connection
#    - After reconnecting, see if the issue recurs. Note any error messages or patterns (time of day, specific apps).
#
# 5) Contact Your ISP
#    - If the problem persists, reach out to your internet service provider to check for outages or line problems.
#
# Let me know how it goes after these steps or if you need more help!
# --------------------------------------------------
#
# **Support Resolution**
# Task is completed with summary: No handoff agent name provided and no human response function set. Ending task.

# %% [markdown]
# ## 6. Human-in-the-Loop Systems
#
# Sometimes you need human input during agent interactions. Here's how to implement human-in-the-loop systems.

# %%
# Custom manager that requests human input
class HumanInTheLoopManager(RoundRobinGroupChatManager):
    """Manager that requests human input after specific conditions."""
    
    @override
    async def should_request_user_input(self, chat_history: ChatHistory) -> BooleanResult:
        """Request user input after every 2 agent exchanges."""
        agent_messages = [msg for msg in chat_history.messages if msg.role == AuthorRole.ASSISTANT]
        
        if len(agent_messages) >= 2 and len(agent_messages) % 2 == 0:
            return BooleanResult(
                result=True,
                reason="Requesting user feedback after agent exchanges"
            )
        
        return BooleanResult(
            result=False,
            reason="No user input needed yet"
        )

# Simple human response function for demonstration
def get_human_response(chat_history: ChatHistory) -> ChatMessageContent:
    """Get human input (simulated for this example)."""
    # In a real application, this would get actual user input
    responses = [
        "That's interesting! Can you elaborate on the benefits?",
        "I like the first approach better. Can you refine it?",
        "Good work! Please finalize the solution."
    ]
    
    # Simulate human response based on conversation length
    response_index = min(len(chat_history.messages) // 4, len(responses) - 1)
    human_input = responses[response_index]
    
    print(f"👤 Human: {human_input}")
    return ChatMessageContent(role=AuthorRole.USER, content=human_input)

print("✅ Human-in-the-loop components created!")
# Out:
# ✅ Human-in-the-loop components created!

# %%
# Create collaborative agents
def create_collaborative_agents() -> list[Agent]:
    """Create agents that work well with human feedback."""
    
    strategist = ChatCompletionAgent(
        name="Strategist",
        description="A strategic planner.",
        instructions="You develop high-level strategies and adapt based on feedback. Be responsive to human input.",
        service=chat_completion,
    )
    
    implementer = ChatCompletionAgent(
        name="Implementer",
        description="A solution implementer.",
        instructions="You create detailed implementation plans based on strategies. Incorporate human feedback.",
        service=chat_completion,
    )
    
    return [strategist, implementer]

# Create human-in-the-loop orchestration
collaborative_agents = create_collaborative_agents()
human_loop_orchestration = GroupChatOrchestration(
    members=collaborative_agents,
    manager=HumanInTheLoopManager(
        max_rounds=6,
        human_response_function=get_human_response,
    ),
    agent_response_callback=agent_response_callback,
)

print("✅ Human-in-the-loop orchestration created!")
# Out:
# ✅ Human-in-the-loop orchestration created!

# %%
# Test human-in-the-loop system
runtime = InProcessRuntime()
runtime.start()

print("🎯 Collaborative Project: Remote Team Productivity")
print("=" * 60)

try:
    orchestration_result = await human_loop_orchestration.invoke(
        task="Develop a strategy to improve remote team productivity and collaboration.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get()
    print(f"\n**Final Collaborative Solution**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Collaborative Project: Remote Team Productivity
# ============================================================
# **Strategist**
# Here’s a high-level, phased strategy for boosting productivity and collaboration across your remote team. You can tailor each step to your organization’s size, culture and tooling.
#
# Phase 1 – Discovery & Alignment
# 1. Audit current state
#    • Survey team on pain points, tool-usage and communication gaps
#    • Review existing workflows, meeting cadences and project metrics
# 2. Define clear objectives
#    • Establish 2–4 key productivity and collaboration goals (e.g., reduce task hand-off ti... [truncated]
# --------------------------------------------------
# **Implementer**
# Implementation Plan: Improving Remote Team Productivity & Collaboration
#
# Below is a 12-week rollout plan with clear tasks, owners, checkpoints and feedback loops. You can tailor timing or team size as needed.
#
# --------------------------------
# Phase 1 (Weeks 1–2): Discovery & Alignment
# Objective: Build shared situational awareness and define measurable goals.
#
# 1. Kickoff & Roles
#   • Owner: Program Manager (PM)
#   • Deliverable: Project charter, RACI matrix, Slack channel “#remote-initiat... [truncated]
# --------------------------------------------------
# 👤 Human: I like the first approach better. Can you refine it?
# **Strategist**
# Here’s a tightened, more actionable version of the four-phase strategy—still high-level but with extra clarity on what “good” looks like, sample deliverables and suggested metrics. You can adjust timelines, owners and tooling to fit your organization.
#
# PHASE 1 – DISCOVERY & ALIGNMENT
# Goal: Build a shared diagnosis, define success criteria and secure the resources to execute.
#
# 1. Audit Current State
#    • Deliverables
#      – 5-minute “remote work” pulse survey (tools used, pain points, tim... [truncated]
# --------------------------------------------------
# **Implementer**
# Below is a tighter, more actionable four-phase playbook—still high-level but with clear “what good looks like,” sample deliverables, suggested metrics and rough timing.  You can swap in your preferred tools, owners or exact dates.
#
# PHASE 1 – FOUNDATION (Weeks 1–2)
# Goal: Build a shared understanding, define success, secure resources.
#
# • 1.1 Form a Core Working Group
#   – Who: 1 × Program Lead, 1 × People Ops partner, 1 × Tech/IT rep, 1–2 team-lead champions
#   – Deliverable: Charter (scope, r... [truncated]
# --------------------------------------------------
# 👤 Human: Good work! Please finalize the solution.
# **Strategist**
# Finalized Four-Phase Playbook for Remote Team Productivity & Collaboration
#
# Phase 1 – Foundation (Weeks 1–2)
# Goal: Build shared understanding, define success criteria and secure resources.
#
# • Form Core Working Group
#   – Who: Program Lead, People Ops partner, IT/DevOps rep, 2 team-lead champions
#   – Deliverable: Project charter (scope, roles, meeting cadence)
#
# • Audit “As-Is” State
#   – Pulse survey (5–7 questions on tools, pain points, meeting load)
#   – 15-min interviews with 2–3 re... [truncated]
# --------------------------------------------------
# **Implementer**
# Here’s the final consolidated plan—ready for launch.
#
# 1) Phase 1: Foundation (Weeks 1–2)
# • Core Working Group formed (Program Lead, People Ops, IT/DevOps, 2 team leads)
# • Audit “As-Is” (pulse survey, 15-min interviews, meeting-hours & tool-usage data) → one-slide summary
# • SMART Objectives & KPIs set (e.g., reduce cycle time 5→4 days; cut meeting hours 10%; ≥70% satisfaction) → 3-month roadmap + scorecard
# • Leadership buy-in secured (exec deck, budget & sponsor)
#
# Key Metrics by Week 2:... [truncated]
# --------------------------------------------------
# 👤 Human: Good work! Please finalize the solution.
#
# **Final Collaborative Solution**
# Good work! Please finalize the solution.

# %% [markdown]
# ## 🎉 Congratulations!
#
# You've successfully completed the Multi-Agent Orchestration tutorial! Here's what you've mastered:
#
# ### ✅ Orchestration Patterns:
# 1. **Group Chat Orchestration** - Round-robin managers for structured conversations
# 2. **Concurrent Processing** - Parallel agent execution with structured outputs
# 3. **Sequential Workflows** - Pipeline-based processing with streaming capabilities
# 4. **LLM-Based Group Chat Manager** - AI-powered intelligent speaker selection
# 5. **Handoff Systems** - Specialized agent routing for complex workflows
# 6. **Human-in-the-Loop** - Interactive agent workflows with user input
#
# ### 🔧 Key Concepts:
# - **Runtime Management** - Using `InProcessRuntime` for agent execution
# - **Callback Functions** - Monitoring agent responses and function calls
# - **Streaming Integration** - Real-time updates in orchestration workflows
# - **Structured Outputs** - Consistent results across multiple agents
# - **Agent Specialization** - Creating focused agents with specific roles
# - **Intelligent Mediation** - Using LLM to make orchestration decisions
#
# ### 🤖 Advanced Features:
# - **AI-Powered Selection** - LLM-based managers that understand conversation context
# - **Reasoning and Transparency** - Managers that explain their decisions
# - **Adaptive Termination** - Smart detection of when discussions should end
# - **Context-Aware Routing** - Intelligent handoffs based on conversation content
#
# ### 📚 Recommended Next step:
# - Review [Semantic Kernel Samples](https://github.com/microsoft/semantic-kernel/tree/main/python/samples)
#
# ### 🤝 Community
# - Check out the [Developer Blog](https://devblogs.microsoft.com/semantic-kernel/)
#
# Excellent work! You're now ready to start building multi-agent systems. 🚀🤖
