# %% [markdown]
# # Advanced Semantic Kernel - Multi-Agent Systems & Orchestration
#
# Welcome to the advanced tutorial! This notebook builds on the basics to explore sophisticated multi-agent systems, orchestration patterns, and production-ready features.
#
# ## Prerequisites
#
# Before starting this tutorial, make sure you've completed the **Semantic Kernel Basics** notebook. You should be familiar with:
# - Basic agent creation and configuration
# - Chat completion services
# - Plugins and function calling
# - Conversation threads
#
# ## What You'll Learn
#
# - **Advanced Agent Features**: Streaming, reasoning models, structured outputs
# - **Multi-Agent Orchestration**: Different patterns for agent collaboration
# - **Human-in-the-Loop Systems**: Interactive agent workflows
# - **Production Considerations**: Error handling, performance, best practices
#
# ## Resources
# - [Agent Orchestration Guide](https://learn.microsoft.com/en-us/semantic-kernel/agents/orchestration/)
# - [Multi-Agent Systems](https://learn.microsoft.com/en-us/semantic-kernel/agents/)
# - [Structured Outputs](https://learn.microsoft.com/en-us/semantic-kernel/concepts/structured-outputs)
#
# Let's dive into the advanced features!

# %% [markdown]
# ## Setup and Imports
#
# Let's start by importing all the necessary modules for advanced features.

# %%
import asyncio
import json
from typing import Annotated
import os
from dotenv import load_dotenv
from pydantic import BaseModel

# Core Semantic Kernel imports
from semantic_kernel import Kernel
from semantic_kernel.agents import Agent, ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion, OpenAIChatCompletion
from semantic_kernel.connectors.ai.open_ai import OpenAIChatPromptExecutionSettings, AzureChatPromptExecutionSettings
from semantic_kernel.functions import kernel_function, KernelArguments
from semantic_kernel.contents import ChatMessageContent, TextContent, StreamingChatMessageContent
from semantic_kernel.contents.utils.author_role import AuthorRole
from semantic_kernel.contents.chat_history import ChatHistory
from semantic_kernel.contents import FunctionCallContent, FunctionResultContent

# Advanced orchestration imports
from semantic_kernel.agents import (
    GroupChatOrchestration, 
    RoundRobinGroupChatManager,
    ConcurrentOrchestration,
    SequentialOrchestration,
    HandoffOrchestration,
    OrchestrationHandoffs
)
from semantic_kernel.agents.runtime import InProcessRuntime
from semantic_kernel.agents.orchestration.tools import structured_outputs_transform
from semantic_kernel.agents.orchestration.group_chat import BooleanResult, GroupChatManager, MessageResult, StringResult
from semantic_kernel.connectors.ai.prompt_execution_settings import PromptExecutionSettings
from semantic_kernel.prompt_template import KernelPromptTemplate, PromptTemplateConfig
from typing_extensions import override

# Load environment variables
load_dotenv()

print("✅ Advanced imports loaded successfully!")
# Out:
# ✅ Advanced imports loaded successfully!

# %%
# Configure the main chat completion service
chat_completion = AzureChatCompletion(
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    deployment_name=os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME"),
)

# Configure reasoning model (if available)
reasoning_completion = None
if os.getenv("AZURE_REASONING_ENDPOINT"):
    reasoning_completion = AzureChatCompletion(
        api_key=os.getenv("AZURE_REASONING_API_KEY"),
        endpoint=os.getenv("AZURE_REASONING_ENDPOINT"),
        deployment_name=os.getenv("AZURE_REASONING_DEPLOYMENT_NAME"),
        instruction_role="developer",
    )
    print("✅ Reasoning model available!")

print("✅ Chat completion services configured!")
# Out:
# ✅ Reasoning model available!
# ✅ Chat completion services configured!

# %% [markdown]
# ## 1. Advanced Agent Features
#
# Let's explore advanced agent capabilities including streaming responses and intermediate step handling.

# %% [markdown]
# ### 1.1 Streaming Responses
#
# Streaming allows you to see responses as they're generated, providing a better user experience for long responses.

# %%
# Create a simple agent for streaming demonstration
streaming_agent = ChatCompletionAgent(
    service=chat_completion,
    name="StreamingExpert",
    instructions="You are an expert who provides detailed explanations. Give comprehensive responses about topics.",
)

# %%
# Example 1: Regular (non-streaming) response
print("📝 Regular Response:")
print("=" * 40)
response = await streaming_agent.get_response(
    messages="Explain the benefits of renewable energy in detail."
)
print(response.message.content)

print("\n" + "=" * 40)
# Out:
# 📝 Regular Response:
# ========================================
# Here is a detailed overview of the key benefits associated with renewable energy:
#
# 1. Environmental Benefits
#    • Reduction of Greenhouse Gas Emissions
#      – Renewables such as wind, solar and hydroelectric produce little to no carbon dioxide (CO₂) or methane (CH₄) during operation, helping to slow climate change.
#      – Lifecycle emissions (from manufacturing to decommissioning) are far lower than those of coal, oil or natural gas.
#    • Air and Water Quality Improvement
#      – By displacing fossil-fuel combustion, renewables cut down on sulfur dioxide (SO₂), nitrogen oxides (NOₓ) and particulate emissions, leading to fewer smog-related illnesses.
#      – They consume far less water than thermal power plants, easing stress on rivers, lakes and aquifers.
#    • Biodiversity Preservation
#      – Well-planned renewable installations can minimize impacts on wildlife and habitats compared with mining, drilling and extensive infrastructure needed for fossil fuels.
#
# 2. Economic Benefits
#    • Stable and Predictable Energy Costs
#      – Once installed, the “fuel” (sunlight, wind, water flow) is free, insulating consumers from volatile fossil-fuel prices.
#      – Long-term power purchase agreements (PPAs) lock in purchase prices, aiding budgeting for utilities and businesses.
#    • Job Creation and Local Economic Growth
#      – Manufacturing, installation, maintenance and R&D in renewables employ millions worldwide.
#      – Many projects are sited in rural or economically depressed regions, bringing investment, training and infrastructure upgrades.
#    • Reduced Operating and Health-Related Costs
#      – Lower emissions translate into fewer health issues (asthma, cardiovascular disease), which reduces public healthcare expenditures.
#      – Less environmental remediation is needed when renewables replace polluting facilities.
#
# 3. Energy Security and Reliability
#    • Diversification of Energy Mix
#      – A broad portfolio—solar, wind, geothermal, biomass, hydro—reduces dependence on any single fuel or supplier.
#    • Decentralization and Resilience
#      – Distributed solar arrays or small wind farms can continue operating when centralized plants or grids face outages, enhancing grid resilience during storms or blackouts.
#      – Microgrids and energy storage paired with renewables support critical facilities (hospitals, emergency services) during emergencies.
#    • Reduced Geopolitical Risks
#      – Nations relying more on domestic renewable resources are less exposed to geopolitical conflicts, trade disputes or price shocks tied to imported oil and gas.
#
# 4. Public Health Benefits
#    • Cleaner Air and Fewer Pollutants
#      – By eliminating emissions of particulates and toxic gases, renewables lower rates of respiratory and cardiovascular illnesses.
#    • Waterborne Disease Reduction
#      – Thermal power plants can heat or pollute water sources; renewables like wind and solar avoid these impacts, safeguarding drinking water and aquatic ecosystems.
#    • Fewer Industrial Accidents
#      – Solar panels and wind turbines involve less hazardous on-site fuel handling than coal mines or oil rigs, reducing workplace injuries and fatalities.
#
# 5. Technological Innovation and Industrial Growth
#    • R&D Spillovers
#      – Advances in battery storage, smart grid management, and energy efficiency techniques often emerge alongside renewable deployments, benefiting other sectors.
#    • Economies of Scale and Learning Curves
#      – As more wind turbines and solar panels are produced and deployed, unit costs drop, accelerating adoption and creating further innovation incentives.
#    • Synergies with Digital Technologies
#      – Integration with IoT sensors, AI-driven forecasting and demand-response platforms optimizes generation and consumption patterns.
#
# 6. Social and Equity Advantages
#    • Energy Access for Underserved Communities
#      – Off-grid and mini-grid solar systems bring electricity to remote or low-income areas where extending conventional grids is prohibitively expensive.
#    • Community Ownership Models
#      – Cooperatives and community-based projects allow local residents to invest in and profit from renewable installations, fostering local engagement and economic returns.
#    • Alignment with Sustainable Development Goals (SDGs)
#      – Renewable energy supports multiple UN SDGs including affordable and clean energy (Goal 7), climate action (Goal 13), health (Goal 3) and sustainable cities (Goal 11).
#
# Summary
# Renewable energy not only curtails pollution and greenhouse-gas emissions but also drives economic growth, strengthens energy security, promotes public health and fosters technological progress. By diversifying energy supplies, creating local jobs and empowering communities, renewables form a cornerstone of a resilient, sustainable energy future.
#
# ========================================

# %%
# Example 2: Streaming response using invoke_stream()
print("🌊 Streaming Response:")
print("=" * 40)
async for streaming_response in streaming_agent.invoke_stream(
    messages="Explain the challenges of implementing AI in healthcare."
):
    # This shows the response as it's being generated in real-time
    print(streaming_response.content, end="", flush=True)

print("\n\n✅ Streaming examples completed!")

# Create an agent with the analysis plugin for the next section
analysis_agent = ChatCompletionAgent(
    service=chat_completion,
    name="AnalysisExpert",
    instructions="You are an expert analyst. Use your tools to provide thorough analysis and recommendations.",
    plugins=[AnalysisPlugin()]
)

print("✅ Analysis agent created for next section!")
# Out:
# 🌊 Streaming Response:
# ========================================
# Implementing AI in healthcare holds great promise but also faces a range of interconnected challenges. Broadly, they can be grouped into technical, organizational, regulatory, ethical, and cultural categories:
#
# 1. Data Quality and Availability
#    • Fragmented systems: Medical records often reside in disparate systems (EHRs, lab databases, imaging archives) that don’t communicate easily.
#    • Incomplete or inconsistent data: Missing fields, variable coding practices, and unstructured notes hamper algorithm training.
#    • Labeling requirements: Supervised machine-learning models require expertly annotated data (e.g., images labeled by radiologists), which is time-consuming and expensive to produce.
#
# 2. Privacy, Security, and Compliance
#    • Patient confidentiality: AI solutions need to comply with laws such as HIPAA in the U.S., GDPR in Europe, and other local regulations, ensuring no unauthorized disclosure of protected health information.
#    • Cybersecurity risks: Centralizing large datasets for AI can create attractive targets for hackers; robust encryption, access controls, and audit trails are essential.
#    • De-identification limits: Truly anonymizing data without destroying its clinical value is challenging—there’s always a risk of re-identification.
#
# 3. Algorithmic Bias and Fairness
#    • Uneven representation: Training datasets often under-represent minorities or rare conditions, leading to models that perform poorly on those groups.
#    • Amplified disparities: If unchecked, AI systems can perpetuate or even worsen existing health disparities (e.g., by under-detecting disease in certain populations).
#    • Ongoing monitoring: Ensuring fairness requires regular auditing of model performance across demographic slices.
#
# 4. Validation and Generalizability
#    • Overfitting to local data: An algorithm trained at one hospital may not work well at another due to differences in equipment, patient demographics, or clinical protocols.
#    • Prospective clinical trials: Demonstrating real-world benefit typically requires time- and resource-intensive studies, akin to drug trials.
#    • Continuous recalibration: Clinical environments evolve, so AI models must be monitored and updated to maintain accuracy and safety.
#
# 5. Explainability and Trust
#    • “Black box” concerns: Many high-performance models (e.g., deep neural networks) offer little insight into how they arrive at decisions, making clinicians uneasy about relying on them.
#    • Regulatory expectations: Authorities increasingly demand interpretable or at least auditable decision-making pathways for AI used in patient care.
#    • User acceptance: Clinician and patient trust grows when AI outputs are transparent or accompanied by confidence measures and clear reasoning.
#
# 6. Integration into Clinical Workflows
#    • Workflow disruption: AI tools must slot seamlessly into existing electronic health records, order-entry systems, and care pathways; otherwise they can slow down clinicians rather than speed them up.
#    • Training and support: Staff need education on when and how to use AI recommendations, as well as clarity about roles and responsibilities.
#    • Alert fatigue: Poorly tuned decision-support systems can generate excessive warnings, leading users to ignore or override valid alerts.
#
# 7. Regulatory and Legal Hurdles
#    • Evolving frameworks: Regulatory agencies are still developing clear pathways for approving AI/ML–based medical devices and software, which can delay deployment.
#    • Liability concerns: It’s often unclear who is accountable if an AI–influenced decision leads to patient harm—the clinician, the hospital, the software developer, or a combination.
#    • Reimbursement models: Payers may not have established codes or criteria to reimburse for AI-driven diagnostics or care recommendations, limiting financial incentives.
#
# 8. Ethical and Social Considerations
#    • Patient consent: Transparent communication about how patient data are used for AI development (and possibly monetized) is vital.
#    • Equity of access: Cutting-edge AI solutions may initially be available only at well-funded centers, further widening the gap between resource-rich and resource-poor settings.
#    • Human oversight: Balancing automation with the need for human judgment is essential—clinicians must retain the final say and be empowered to override AI suggestions.
#
# 9. Infrastructure and Cost
#    • Compute resources: Training large AI models often requires significant GPU/TPU capacity and specialized hardware, which not all institutions can afford.
#    • Maintenance and support: Once deployed, AI systems need ongoing IT support, cybersecurity updates, and model maintenance.
#    • Scalability: Pilots may work in a controlled environment, but scaling to thousands of patients or multiple sites brings additional challenges in governance and performance management.
#
# In summary, successful implementation of AI in healthcare demands not only robust algorithms but also high-quality and interoperable data, transparent regulatory pathways, clinician engagement and training, ethical guardrails, and the right technical and organizational infrastructure. Addressing each of these areas in tandem is key to unlocking AI’s full potential to improve patient outcomes, streamline workflows, and reduce costs.
#
# ✅ Streaming examples completed!
# ✅ Analysis agent created for next section!

# %% [markdown]
# ### 1.2 Intermediate Steps with invoke()
#
# **Understanding Agent Methods:**
#
# - **`get_response()`**: Provides the final response only - blocks until the agent is completely done processing
# - **`invoke()`**: Allows you to see the agent's step-by-step thinking process, including intermediate function calls and results
# - **`invoke_stream()`**: Provides real-time streaming of the response as it's being generated
#
# The `invoke()` method is particularly useful when you want to understand how the agent is working with plugins and function calls.

# %%
class AnalysisPlugin:
    """Plugin that provides analysis capabilities."""
    
    @kernel_function(description="Analyze a topic and provide insights.")
    def analyze_topic(self, topic: Annotated[str, "The topic to analyze"]) -> str:
        # Simulate analysis processing
        return f"Analysis of '{topic}': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility."
    
    @kernel_function(description="Generate recommendations based on analysis.")
    def generate_recommendations(self, analysis: Annotated[str, "The analysis to base recommendations on"]) -> str:
        return "Recommendations: 1) Conduct further research, 2) Develop a prototype, 3) Test with users, 4) Iterate based on feedback."

# %%
async def handle_intermediate_steps(message: ChatMessageContent) -> None:
    """Handle intermediate steps in the agent's processing."""
    for item in message.items or []:
        if isinstance(item, FunctionResultContent):
            print(f"🔧 Function Result: {item.result}")
        elif isinstance(item, FunctionCallContent):
            print(f"📞 Function Call: {item.name} with arguments: {item.arguments}")
        else:
            print(f"💭 {message.name}: {message.content}")

# Test intermediate steps
task = "Analyze the potential of AI-powered educational tools and provide recommendations."
print(f"🎯 Task: {task}")
print("=" * 60)

async for response in analysis_agent.invoke(
    messages=task,
    on_intermediate_message=handle_intermediate_steps
):
    print(f"✅ Final Response from {response.name}: {response.content}")
# Out:
# 🎯 Task: Analyze the potential of AI-powered educational tools and provide recommendations.
# ============================================================
# 📞 Function Call: AnalysisPlugin-analyze_topic with arguments: {"topic":"AI-powered educational tools"}
# 🔧 Function Result: Analysis of 'AI-powered educational tools': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility.
# 📞 Function Call: AnalysisPlugin-generate_recommendations with arguments: {"analysis":"Analysis of 'AI-powered educational tools': This is a complex topic that requires consideration of market trends, user needs, and technical feasibility."}
# 🔧 Function Result: Recommendations: 1) Conduct further research, 2) Develop a prototype, 3) Test with users, 4) Iterate based on feedback.
# ✅ Final Response from AnalysisExpert: Analysis of AI-Powered Educational Tools
#
# 1. Market Trends
#    • Rapid Growth: The global edtech market has been expanding at over 15% annually, driven by increased remote and hybrid learning models.
#    • Personalization Demand: Learners seek tailored content—AI can deliver adaptive lessons that adjust difficulty, pace, and presentation style in real time.
#    • Investment Activity: Venture capital continues to flow into AI-driven tutoring, assessment, and content-generation platforms, signaling strong investor confidence.
#
# 2. User Needs
#    • Students: Want interactive, engaging experiences and instant feedback. AI can simulate one-on-one tutoring, answer questions on demand, and provide real-time progress tracking.
#    • Educators: Need tools to automate grading, generate customized materials, and obtain analytics on class performance. AI can reduce administrative burden and highlight at-risk learners.
#    • Institutions: Require scalable solutions that integrate with existing Learning Management Systems (LMS), ensure data privacy, and demonstrate measurable impact on outcomes.
#
# 3. Technical Feasibility
#    • NLP and Content Generation: Large language models can create explanations, quizzes, and multimedia resources, but must be fine-tuned with educational data to ensure accuracy and appropriateness.
#    • Adaptive Learning Algorithms: Reinforcement learning and Bayesian knowledge tracing enable dynamic adjustment of content pathways. This requires robust data collection and user modeling.
#    • Integration & Infrastructure: Cloud-based APIs facilitate rapid deployment, but latency, cost, and compliance with data protection regulations (e.g., GDPR, COPPA) must be managed.
#
# 4. Opportunities & Challenges
#    • Accessibility & Equity: AI tools can democratize quality education for underserved populations, but require investment in connectivity and device access.
#    • Ethical Considerations: Bias in training data may perpetuate inequities. Transparent algorithms and human-in-the-loop oversight are critical.
#    • Teacher Collaboration: Educators must be involved in tool design to ensure solutions address actual classroom needs and foster buy-in.
#
# Recommendations
#
# 1. Conduct Comprehensive User Research
#    • Interview students, teachers, and administrators across diverse settings to identify unmet needs.
#    • Map existing workflows and pain points in lesson planning, delivery, and assessment.
#
# 2. Develop a Minimum Viable Prototype (MVP)
#    • Focus on one high-impact feature, such as AI-driven formative assessments or personalized lesson recommendations.
#    • Use modular architecture to allow later scaling into additional subjects or functionalities.
#
# 3. Pilot and Iterate
#    • Partner with a small group of schools or districts for a 3–6 month pilot.
#    • Collect quantitative metrics (e.g., usage rates, learning gains) and qualitative feedback (e.g., user satisfaction, ease of use).
#    • Refine algorithms and interface based on pilot data, addressing any accuracy or bias issues.
#
# 4. Ensure Ethical and Regulatory Compliance
#    • Implement data governance policies, anonymize student data, and secure parental consents where required.
#    • Periodically audit AI outputs for fairness and accuracy; incorporate teacher review steps.
#
# 5. Plan for Scale
#    • Design for interoperability with popular LMS platforms (e.g., Canvas, Moodle).
#    • Establish cloud infrastructure that can dynamically scale to handle peak loads with cost controls.
#    • Develop onboarding and professional development materials for educators.
#
# 6. Measure Impact and Communicate Value
#    • Define key performance indicators (KPIs) such as improved test scores, reduced grading time, and increased engagement.
#    • Publish case studies and white papers to demonstrate ROI for schools and districts.
#
# By following this phased approach—grounded in user insights, ethical AI practices, and scalable technology—you can maximize the potential of AI-powered educational tools to transform teaching and learning.

# %%
# Straming with intermediate steps
async for streaming_response in analysis_agent.invoke_stream(
    messages=task,
    on_intermediate_message=handle_intermediate_steps
):
    print(streaming_response.content, end="", flush=True)
# Out:
# 📞 Function Call: AnalysisPlugin-analyze_topic with arguments: {"topic":"AI-powered educational tools"}
# 🔧 Function Result: Analysis of 'AI-powered educational tools': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility.
# 📞 Function Call: AnalysisPlugin-generate_recommendations with arguments: {"analysis":"Analysis of 'AI-powered educational tools': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility."}
# 🔧 Function Result: Recommendations: 1) Conduct further research, 2) Develop a prototype, 3) Test with users, 4) Iterate based on feedback.
# Analysis of AI-powered educational tools:
#
# 1. Market Trends
#    - Rapid adoption: Schools, universities, and corporate training programs increasingly adopt AI for personalized learning, automated grading, and intelligent tutoring.
#    - Investment growth: Venture capital funding in edtech has surged, with AI-focused startups leading the way.
#    - User expectations: Learners seek customized experiences, real-time feedback, and interactive content.
#
# 2. User Needs
#    - Personalization: Students vary in learning pace, style, and background; AI can tailor content to individual profiles.
#    - Accessibility: AI tools can improve access for students with disabilities via speech-to-text, translation, and adaptive interfaces.
#    - Engagement: Gamified experiences and AI-driven simulations can boost motivation and knowledge retention.
#
# 3. Technical Feasibility
#    - Natural language processing: Advances enable chatbots, automated essay scoring, and real-time Q&A support.
#    - Data requirements: Effective AI models require large, high-quality datasets, raising concerns about privacy and bias.
#    - Integration challenges: Tools must interoperate with existing learning management systems and adhere to educational standards.
#
# 4. Potential Challenges
#    - Ethical considerations: Bias in AI recommendations, data privacy, and surveillance concerns.
#    - Teacher role: Ensuring AI augments rather than replaces human educators.
#    - Cost barriers: Development and deployment costs can be high for underfunded institutions.
#
# Recommendations:
#
# 1. Conduct In-Depth Research
#    - Perform market segmentation to identify high-impact use cases (e.g., K–12, higher education, corporate training).
#    - Assess regulatory environments and data privacy laws in target regions.
#
# 2. Develop a Prototype
#    - Focus on a specific application, such as an AI-driven tutoring chatbot or adaptive learning module.
#    - Leverage open-source AI models and partner with content experts to minimize development costs.
#
# 3. Pilot and User Testing
#    - Collaborate with a small group of educators and students to deploy the prototype in a real-world setting.
#    - Collect quantitative data (engagement metrics, performance improvements) and qualitative feedback (user satisfaction, usability).
#
# 4. Iterate and Enhance
#    - Analyze pilot results to refine algorithms, improve UX, and address ethical concerns (e.g., bias mitigation).
#    - Expand feature set by integrating with student information systems and adding multilingual support.
#
# 5. Scale and Monitor
#    - Develop a phased rollout plan, prioritizing institutions with supportive infrastructure.
#    - Implement robust monitoring for performance, user privacy, and ethical compliance.
#    - Provide ongoing training and support for educators to maximize tool adoption.
#
# By following these steps, organizations can harness the potential of AI-powered educational tools to deliver personalized, engaging, and accessible learning experiences while mitigating risks.

# %% [markdown]
# ### 1.3 Structured Outputs with Pydantic
#
# You can enforce structured responses using Pydantic models, ensuring consistent output format.

# %%
# Define structured output models
class Step(BaseModel):
    explanation: str
    output: str

class MathSolution(BaseModel):
    steps: list[Step]
    final_answer: str

# Create an agent with structured output
settings = AzureChatPromptExecutionSettings()
settings.response_format = MathSolution

math_agent = ChatCompletionAgent(
    service=chat_completion,
    name="MathTutor",
    instructions="You are a math tutor. Solve problems step by step and provide clear explanations.",
    arguments=KernelArguments(settings=settings)
)

# Test structured output
problem = "Solve: 3x + 7 = 22"
print(f"🧮 Problem: {problem}")

response = await math_agent.get_response(messages=problem)
solution = MathSolution.model_validate(json.loads(response.message.content))

print("\n📚 Structured Solution:")
print(solution.model_dump_json(indent=2))
# Out:
# 🧮 Problem: Solve: 3x + 7 = 22
#
# 📚 Structured Solution:
# {
#   "steps": [
#     {
#       "explanation": "Subtract 7 from both sides of the equation 3x + 7 = 22 to isolate the term with x.",
#       "output": "3x = 22 - 7 = 15"
#     },
#     {
#       "explanation": "Divide both sides of the equation 3x = 15 by 3 to solve for x.",
#       "output": "x = 15 ÷ 3 = 5"
#     }
#   ],
#   "final_answer": "x = 5"
# }

# %% [markdown]
# ### 1.4 Reasoning Models (if available)
#
# Some models like O1 provide enhanced reasoning capabilities. Let's test if we have access to reasoning models.

# %%
if reasoning_completion:
    print("🧠 Testing reasoning model...")
    
    reasoning_settings = AzureChatPromptExecutionSettings(
        service_id="reasoning",
        reasoning_effort="high"
    )
    
    reasoning_agent = ChatCompletionAgent(
        name="ReasoningExpert",
        instructions="You are an expert problem solver. Think through complex problems step by step.",
        service=reasoning_completion,
    )
    
    thread = ChatHistoryAgentThread()
    response = await reasoning_agent.get_response(
        messages="Solve: 2x + 3y = 7, 4x - y = 1. Show your reasoning.", 
        thread=thread
    )
    
    print(f"🧠 Reasoning Response: {response.message.content}")

    # Add another user message to the thread
    print("\n🤔 User: Is the solution correct? Explain.")
    response = await reasoning_agent.get_response(
        messages="Is the solution correct? Explain.", 
        thread=thread
    )
    print(f"🧠 Reasoning Response: {response.message.content}")
else:
    print("⚠️ Reasoning model not configured. Skipping reasoning example.")
    print("💡 To enable reasoning, configure AZURE_REASONING_* environment variables.")
# Out:
# 🧠 Testing reasoning model...
# 🧠 Reasoning Response: Here is one clear way (elimination):
#
# 1. Write the system:
#    (1) 2x + 3y = 7
#    (2) 4x –  y = 1
#
# 2. Multiply equation (2) by 3 to align the y-terms:
#    3·(4x – y = 1) ⇒ 12x – 3y = 3
#
# 3. Add this to equation (1):
#    (2x + 3y = 7)
#  + (12x – 3y = 3)
#  ----------------
#    14x        = 10
#
# 4. Solve for x:
#    14x = 10
#    x = 10/14 = 5/7
#
# 5. Substitute x = 5/7 back into, say, equation (2):
#    4x – y = 1
#    4·(5/7) – y = 1
#    20/7 – y = 1
#    –y = 1 – 20/7 = 7/7 – 20/7 = –13/7
#    y = 13/7
#
# Solution: x = 5/7, y = 13/7.
#
# 🤔 User: Is the solution correct? Explain.
# 🧠 Reasoning Response: Yes. To check, substitute x=5/7 and y=13/7 into both equations:
#
# 1. Check 2x + 3y = 7
#    2·(5/7) + 3·(13/7) = (10/7) + (39/7) = 49/7 = 7 ✔
#
# 2. Check 4x – y = 1
#    4·(5/7) – (13/7) = (20/7) – (13/7) = 7/7 = 1 ✔
#
# Since both equations hold true, the solution x = 5/7, y = 13/7 is correct.

# %%
# You can see the reasoning tokens used by the agent
async for message in thread.get_messages():
    print(f"📝 Message from {message.role}: {message.content[:20]}...")
    if message.metadata.get("usage", None):
        print(f"    🔍 Usage: {message.metadata['usage'].model_dump()}")
# Out:
# 📝 Message from AuthorRole.USER: Solve: 2x + 3y = 7, ...
# 📝 Message from AuthorRole.ASSISTANT: Here is one clear wa...
#     🔍 Usage: {'prompt_tokens': 55, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'completion_tokens': 514, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}}
# 📝 Message from AuthorRole.USER: Is the solution corr...
# 📝 Message from AuthorRole.ASSISTANT: Yes. To check, subst...
#     🔍 Usage: {'prompt_tokens': 340, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'completion_tokens': 295, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}}

# %%
await thread.delete()

# %% [markdown]
# ## 2. Multi-Agent Orchestration Patterns
#
# Now let's explore different ways to orchestrate multiple agents working together.

# %% [markdown]
# ### 2.1 Group Chat with Round Robin
#
# Round robin orchestration ensures agents take turns in a specific order.

# %%
def create_content_team() -> list[Agent]:
    """Create a team of content creation agents."""
    
    writer = ChatCompletionAgent(
        name="ContentWriter",
        description="A creative content writer.",
        instructions="You create engaging content. Focus on creativity and readability.",
        service=chat_completion,
    )
    
    editor = ChatCompletionAgent(
        name="ContentEditor",
        description="A content editor and reviewer.",
        instructions="You review and improve content. Focus on clarity, grammar, and flow.",
        service=chat_completion,
    )
    
    return [writer, editor]

def agent_response_callback(message: ChatMessageContent) -> None:
    """Display agent responses."""
    print(f"**{message.name}**")
    print(message.content)
    print("-" * 50)

# Create the group chat
content_agents = create_content_team()
group_chat = GroupChatOrchestration(
    members=content_agents,
    manager=RoundRobinGroupChatManager(max_rounds=3),
    agent_response_callback=agent_response_callback,
)

print("✅ Group chat orchestration created!")
# Out:
# ✅ Group chat orchestration created!

# %%
# Test group chat orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Task: Create content for a sustainable living blog post")
print("=" * 60)

try:
    orchestration_result = await group_chat.invoke(
        task="Create a compelling blog post about sustainable living tips for busy professionals.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get()
    print(f"\n**Final Result**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Task: Create content for a sustainable living blog post
# ============================================================
# **ContentWriter**
# Title: Sustainable Living for Busy Professionals: 8 Simple Habits You Can Start Today
#
# Introduction
# In the whirlwind of meetings, emails, and deadlines, sustainable living can feel like yet another to-do on an ever-growing list. But small, intentional changes to your daily routine not only lighten your environmental footprint—they can also sharpen your focus, boost your well-being, and even save you money. Here are eight practical, time-efficient sustainability tips for busy professionals who want to make a real difference without adding stress to their schedules.
#
# 1. Morning Routine Reset: Reusable Over Disposable
# • Keep a sleek, insulated travel mug in your bag, ready for coffee runs.
# • Swap single-use paper towels for a set of washable cloths by the sink.
# • Opt for a bamboo toothbrush and refillable toothpaste tablets—easy to toss in your toiletry bag and kind to the planet.
#
# Why it works: Reusable items pay for themselves quickly, cut down on waste, and become second nature once they’re part of your go-to routine.
#
# 2. Meal Prep with a Green Twist
# • Choose one night a week for a “meat-less Monday” or “veggie-forward Friday.”
# • Use large glass containers for portioned meals: they’re microwave-safe, easy to clean, and eliminate disposable packaging.
# • Scout local farmer’s markets or subscribe to a small organic produce box for seasonal veggies.
#
# Why it works: Planning ahead saves time, reduces impulse takeout, and supports sustainable farming practices.
#
# 3. Efficient & Eco-Friendly Commutes
# • If public transit or rideshares fit your budget and schedule, give them a try—many systems now offer monthly passes with digital payment options.
# • Explore e-bikes or folding bikes that you can roll into the office and stash under your desk.
# • When driving can’t be avoided, adopt hypermiling techniques: smooth acceleration, maintaining a steady speed, and minimizing idling.
#
# Why it works: Reducing solo driving cuts carbon emissions, eases parking headaches, and can even improve your mood by shifting stress away from traffic jams.
#
# 4. Digital Declutter for the Earth
# • Unsubscribe from promotional emails you never read—servers consume tons of energy storing and sending those messages.
# • Cloud storage vs. external hard drives? Compare the energy footprint and choose a greener provider (many now run on renewable power).
# • Donate or responsibly recycle old electronics at certified e-waste centers.
#
# Why it works: Digital housekeeping not only speeds up your devices but also lowers the unseen carbon toll of our online lives.
#
# 5. Smart Shopping & Minimalist Wardrobe
# • Lean into quality over quantity: pick versatile, durable pieces in neutral colors that mix and match.
# • Explore clothing rental services for special-occasion wear—it saves money, closet space, and reduces fast-fashion waste.
# • Repair before you replace: find a local tailor or cobbler who can extend the lifespan of well-worn favorites.
#
# Why it works: A curated wardrobe reduces decision fatigue each morning while minimizing textile waste.
#
# 6. Green Office Habits
# • Power down monitors, printers, and chargers at the end of the day—many electronics draw “vampire power” even when off.
# • Switch to recycled-content copier paper and eco-friendly ink cartridges.
# • Keep a small potted plant on your desk: it improves air quality and offers a calming, natural touch.
#
# Why it works: Small shifts in the workplace ripple outward, influencing colleagues and cutting utility costs.
#
# 7. Mindful Tech & Travel Packing
# • Digitize boarding passes, itineraries, and work docs to reduce paper waste.
# • Invest in lightweight, reusable travel essentials: silicone toiletry bottles, collapsible water bottles, and compact shopping totes.
# • Choose eco-certified hotels or business-friendly green certifications whenever you travel.
#
# Why it works: Thoughtful packing saves space in your carry-on and promotes sustainable tourism practices.
#
# 8. Weekend Micro-Breaks with a Purpose
# • Take a local trail hike or an urban park walk instead of a drive-through weekend excursion.
# • Volunteer for a beach cleanup, community garden, or tree-planting event—network, reset your mind, and give back in just a few hours.
# • Host a potluck at home using plant-based or locally sourced dishes to connect with friends sustainably.
#
# Why it works: Recharging outdoors or through meaningful social activity combats burnout and deepens your connection to the environment.
#
# Conclusion
# Embracing sustainability isn’t about monumental life overhauls—it’s about weaving in small, intentional choices that align with your busy lifestyle. Start with one or two of these tips this week. As they become habit, layer on the next. In no time, you’ll discover that living green can feel less like a chore and more like a powerful path to personal productivity, better health, and a future we can all be proud of. Ready to make today the day you take your first tiny step toward big impact? Let’s go!
# --------------------------------------------------
# **ContentEditor**
# Title: Sustainable Living for Busy Professionals: 8 Simple Habits to Start Today
#
# Introduction
# Between back-to-back meetings, email overload, and looming deadlines, adding a “sustainable lifestyle” to your to-do list can feel overwhelming. Yet even small, intentional changes can reduce your environmental impact—and they often boost productivity, improve well-being, and save you money. Here are eight quick, manageable habits that busy professionals can adopt right now.
#
# 1. Swap Single-Use for Reusable
# • Carry a quality, insulated travel mug for coffee and tea.
# • Replace paper towels with a set of washable cloths by your sink.
# • Choose a bamboo toothbrush and refillable toothpaste tablets for your daily routine.
#
# Why it matters: Reusables pay for themselves, eliminate waste, and quickly become second nature.
#
# 2. Meal Prep with Purpose
# • Designate one evening a week for plant-based or semi-vegetarian meals.
# • Use stackable glass containers for portioned lunches—no more wasted packaging.
# • Shop seasonally at farmers’ markets or subscribe to a local organic produce box.
#
# Why it matters: Planning meals saves time, cuts down on takeout, and supports sustainable agriculture.
#
# 3. Rethink Your Commute
# • Try public transit or rideshares if they fit your schedule—monthly digital passes simplify payment.
# • Consider an e-bike or folding bike that you can store indoors.
# • When driving is necessary, practice hypermiling: smooth acceleration, steady speeds, and minimal idling.
#
# Why it matters: Reducing solo car trips lowers carbon emissions, eases parking stress, and can uplift your mood.
#
# 4. Tidy Up Your Digital Life
# • Unsubscribe from newsletters and promotions you don’t read.
# • Choose cloud services powered by renewable energy or compare their carbon footprints.
# • Recycle old devices at certified e-waste centers rather than letting them gather dust.
#
# Why it matters: Digital clutter overloads servers, and recycling electronics prevents hazardous materials from reaching landfills.
#
# 5. Build a Capsule Wardrobe
# • Invest in versatile, high-quality basics in neutral colors that mix and match.
# • Rent formal or occasion-specific attire instead of buying pieces you’ll rarely wear.
# • Repair rather than replace worn items—locate a reliable tailor or cobbler in your area.
#
# Why it matters: A streamlined wardrobe reduces decision fatigue, saves money, and cuts textile waste.
#
# 6. Embrace Green Office Practices
# • Power down all peripherals—monitors, printers and chargers—when you leave.
# • Opt for recycled-content paper and eco-friendly ink cartridges.
# • Add a potted plant to your desk for cleaner air and a touch of nature.
#
# Why it matters: Small changes at work lower energy costs and influence colleagues to follow suit.
#
# 7. Pack Smart for Business Trips
# • Store boarding passes and documents digitally to eliminate paper.
# • Use silicone toiletry bottles, collapsible water bottles and reusable shopping totes.
# • Select hotels with recognized green certifications or eco-friendly programs.
#
# Why it matters: Thoughtful packing reduces waste, lightens your load, and supports sustainable tourism.
#
# 8. Make Weekends Count
# • Swap drive-through excursions for local hikes or park walks.
# • Volunteer at community cleanups, gardens or tree plantings—network while giving back.
# • Host a plant-powered potluck to socialize sustainably and explore new recipes.
#
# Why it matters: Outdoor activities and community involvement help you recharge without harming the planet.
#
# Conclusion
# Sustainable living isn’t about major lifestyle overhauls—it’s about stacking small, intentional choices that align with your busy schedule. Pick one or two habits to start this week. As they become routines, add the next tip. Over time, these manageable shifts will yield big environmental benefits and enhance your personal productivity, health and peace of mind. Ready to make today your first step toward a greener future? Let’s get started!
# --------------------------------------------------
# **ContentWriter**
# Title: Sustainable Living for Busy Professionals: 8 Simple Habits to Start Today
#
# Introduction
# Between back-to-back meetings, email overload, and looming deadlines, adding a “sustainable lifestyle” to your to-do list can feel overwhelming. Yet even small, intentional changes can reduce your environmental impact—and they often boost productivity, improve well-being, and save you money. Here are eight quick, manageable habits that busy professionals can adopt right now.
#
# 1. Swap Single-Use for Reusable
# • Carry a quality, insulated travel mug for coffee and tea.
# • Replace paper towels with a set of washable cloths by your sink.
# • Choose a bamboo toothbrush and refillable toothpaste tablets for your daily routine.
# Why it matters: Reusables pay for themselves, eliminate waste, and quickly become second nature.
#
# 2. Meal Prep with Purpose
# • Designate one evening a week for plant-based or semi-vegetarian meals.
# • Use stackable glass containers for portioned lunches—no more wasted packaging.
# • Shop seasonally at farmers’ markets or subscribe to a local organic produce box.
# Why it matters: Planning meals saves time, cuts down on takeout, and supports sustainable agriculture.
#
# 3. Rethink Your Commute
# • Try public transit or rideshares if they fit your schedule—monthly digital passes simplify payment.
# • Consider an e-bike or folding bike that you can store indoors.
# • When driving is necessary, practice hypermiling: smooth acceleration, steady speeds, and minimal idling.
# Why it matters: Reducing solo car trips lowers carbon emissions, eases parking stress, and can uplift your mood.
#
# 4. Tidy Up Your Digital Life
# • Unsubscribe from newsletters and promotions you don’t read.
# • Choose cloud services powered by renewable energy or compare their carbon footprints.
# • Recycle old devices at certified e-waste centers rather than letting them gather dust.
# Why it matters: Digital clutter overloads servers, and recycling electronics prevents hazardous materials from reaching landfills.
#
# 5. Build a Capsule Wardrobe
# • Invest in versatile, high-quality basics in neutral colors that mix and match.
# • Rent formal or occasion-specific attire instead of buying pieces you’ll rarely wear.
# • Repair rather than replace worn items—locate a reliable tailor or cobbler in your area.
# Why it matters: A streamlined wardrobe reduces decision fatigue, saves money, and cuts textile waste.
#
# 6. Embrace Green Office Practices
# • Power down all peripherals—monitors, printers and chargers—when you leave.
# • Opt for recycled-content paper and eco-friendly ink cartridges.
# • Add a potted plant to your desk for cleaner air and a touch of nature.
# Why it matters: Small changes at work lower energy costs and influence colleagues to follow suit.
#
# 7. Pack Smart for Business Trips
# • Store boarding passes and documents digitally to eliminate paper.
# • Use silicone toiletry bottles, collapsible water bottles and reusable shopping totes.
# • Select hotels with recognized green certifications or eco-friendly programs.
# Why it matters: Thoughtful packing reduces waste, lightens your load, and supports sustainable tourism.
#
# 8. Make Weekends Count
# • Swap drive-through excursions for local hikes or park walks.
# • Volunteer at community cleanups, gardens or tree plantings—network while giving back.
# • Host a plant-powered potluck to socialize sustainably and explore new recipes.
# Why it matters: Outdoor activities and community involvement help you recharge without harming the planet.
#
# Conclusion
# Sustainable living isn’t about major lifestyle overhauls—it’s about stacking small, intentional choices that align with your busy schedule. Pick one or two habits to start this week. As they become routines, add the next tip. Over time, these manageable shifts will yield big environmental benefits and enhance your personal productivity, health, and peace of mind. Ready to make today your first step toward a greener future? Let’s get started!
# --------------------------------------------------
#
# **Final Result**
# Title: Sustainable Living for Busy Professionals: 8 Simple Habits to Start Today
#
# Introduction
# Between back-to-back meetings, email overload, and looming deadlines, adding a “sustainable lifestyle” to your to-do list can feel overwhelming. Yet even small, intentional changes can reduce your environmental impact—and they often boost productivity, improve well-being, and save you money. Here are eight quick, manageable habits that busy professionals can adopt right now.
#
# 1. Swap Single-Use for Reusable
# • Carry a quality, insulated travel mug for coffee and tea.
# • Replace paper towels with a set of washable cloths by your sink.
# • Choose a bamboo toothbrush and refillable toothpaste tablets for your daily routine.
# Why it matters: Reusables pay for themselves, eliminate waste, and quickly become second nature.
#
# 2. Meal Prep with Purpose
# • Designate one evening a week for plant-based or semi-vegetarian meals.
# • Use stackable glass containers for portioned lunches—no more wasted packaging.
# • Shop seasonally at farmers’ markets or subscribe to a local organic produce box.
# Why it matters: Planning meals saves time, cuts down on takeout, and supports sustainable agriculture.
#
# 3. Rethink Your Commute
# • Try public transit or rideshares if they fit your schedule—monthly digital passes simplify payment.
# • Consider an e-bike or folding bike that you can store indoors.
# • When driving is necessary, practice hypermiling: smooth acceleration, steady speeds, and minimal idling.
# Why it matters: Reducing solo car trips lowers carbon emissions, eases parking stress, and can uplift your mood.
#
# 4. Tidy Up Your Digital Life
# • Unsubscribe from newsletters and promotions you don’t read.
# • Choose cloud services powered by renewable energy or compare their carbon footprints.
# • Recycle old devices at certified e-waste centers rather than letting them gather dust.
# Why it matters: Digital clutter overloads servers, and recycling electronics prevents hazardous materials from reaching landfills.
#
# 5. Build a Capsule Wardrobe
# • Invest in versatile, high-quality basics in neutral colors that mix and match.
# • Rent formal or occasion-specific attire instead of buying pieces you’ll rarely wear.
# • Repair rather than replace worn items—locate a reliable tailor or cobbler in your area.
# Why it matters: A streamlined wardrobe reduces decision fatigue, saves money, and cuts textile waste.
#
# 6. Embrace Green Office Practices
# • Power down all peripherals—monitors, printers and chargers—when you leave.
# • Opt for recycled-content paper and eco-friendly ink cartridges.
# • Add a potted plant to your desk for cleaner air and a touch of nature.
# Why it matters: Small changes at work lower energy costs and influence colleagues to follow suit.
#
# 7. Pack Smart for Business Trips
# • Store boarding passes and documents digitally to eliminate paper.
# • Use silicone toiletry bottles, collapsible water bottles and reusable shopping totes.
# • Select hotels with recognized green certifications or eco-friendly programs.
# Why it matters: Thoughtful packing reduces waste, lightens your load, and supports sustainable tourism.
#
# 8. Make Weekends Count
# • Swap drive-through excursions for local hikes or park walks.
# • Volunteer at community cleanups, gardens or tree plantings—network while giving back.
# • Host a plant-powered potluck to socialize sustainably and explore new recipes.
# Why it matters: Outdoor activities and community involvement help you recharge without harming the planet.
#
# Conclusion
# Sustainable living isn’t about major lifestyle overhauls—it’s about stacking small, intentional choices that align with your busy schedule. Pick one or two habits to start this week. As they become routines, add the next tip. Over time, these manageable shifts will yield big environmental benefits and enhance your personal productivity, health, and peace of mind. Ready to make today your first step toward a greener future? Let’s get started!

# %% [markdown]
# ### 2.2 Concurrent Orchestration
#
# Concurrent orchestration allows multiple agents to work on the same task simultaneously.

# %%
def create_research_team() -> list[Agent]:
    """Create a team of research specialists."""
    
    tech_researcher = ChatCompletionAgent(
        name="TechResearcher",
        instructions="You are a technology research expert. Analyze questions from a technical perspective.",
        service=chat_completion,
    )
    
    market_researcher = ChatCompletionAgent(
        name="MarketResearcher",
        instructions="You are a market research expert. Analyze questions from a business and market perspective.",
        service=chat_completion,
    )
    
    return [tech_researcher, market_researcher]

# Create concurrent orchestration
research_agents = create_research_team()
concurrent_orchestration = ConcurrentOrchestration(members=research_agents)

print("✅ Concurrent orchestration created!")
# Out:
# ✅ Concurrent orchestration created!

# %%
# Test concurrent orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Research Topic: Electric Vehicle Market")
print("=" * 50)

try:
    orchestration_result = await concurrent_orchestration.invoke(
        task="Analyze the current state and future prospects of the electric vehicle market.",
        runtime=runtime,
    )
    
    results = await orchestration_result.get(timeout=60)
    
    for result in results:
        print(f"**{result.name}**")
        print(result.content)
        print("-" * 50)
        
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Research Topic: Electric Vehicle Market
# ==================================================
# **TechResearcher**
# Below is a structured, technical overview of the electric vehicle (EV) market’s current status and its future trajectory.
#
# 1. Market Overview
#    • Global sales and penetration
#      – In 2023, roughly 14 percent of new passenger-car sales worldwide were electric (battery EVs plus plug-in hybrids).
#      – Absolute EV sales surpassed 10 million units, with China accounting for about half, Europe about one-third, and North America around 15 percent.
#    • Leading manufacturers
#      – Tesla remains the largest single EV maker by volume; Volkswagen Group, BYD, Renault–Nissan–Mitsubishi Alliance and Hyundai–Kia follow closely.
#      – New entrants (e.g., Rivian, Lucid, NIO, XPeng) and legacy OEMs with dedicated EV platforms (e.g., GM’s Ultium, Ford’s MEB-derived models) are rapidly expanding.
#    • Regional dynamics
#      – China: aggressive subsidies, local champions, dense urban charging networks.
#      – Europe: strong CO2 regulations, growing fast-charge corridors, rising home charger installations.
#      – North America: federal and state incentives boosting adoption; slower roll-out of public infrastructure compared to China and Europe.
#
# 2. Key Drivers
#    • Regulatory environment
#      – Zero-emission vehicle targets (EU: 100 percent ZEVs by 2035; US: increasing federal tax credits; China: NEV credit system).
#      – Urban low-emission zones and planned bans on new ICE vehicle sales in many markets.
#    • Total cost of ownership (TCO)
#      – Continued battery-cost declines: from > 500 USD/kWh in 2014 to around 120–140 USD/kWh in 2023.
#      – Lower maintenance costs (fewer moving parts, regenerative braking).
#    • Consumer and corporate sustainability commitments
#      – Fleet electrification mandates, ESG reporting pressures, growing environmental awareness.
#
# 3. Technology Trends
#    • Battery chemistry and form factors
#      – NMC (nickel-manganese-cobalt) remains dominant, while high-nickel cathodes (NCA, NCM 811) boost energy density.
#      – Solid-state batteries in pilot production for late-2020s commercialization could double energy density and improve safety.
#    • Fast-charging evolution
#      – Commercial chargers: from 50 kW (2015) to 150–350 kW ultra-fast chargers.
#      – Next steps: Megawatt-class charging for heavy trucks and rapid turnaround.
#    • Power electronics and drivetrains
#      – Silicon carbide (SiC) inverters reducing losses and weight.
#      – Integrated powertrain modules improving packaging efficiency.
#
# 4. Infrastructure and Ecosystem
#    • Public charging networks
#      – China: over 3 million public chargers; Europe: ~800 000; US: ~150 000.
#      – Deployment bottlenecks include grid interconnection delays, permitting, and site acquisition.
#    • Residential and workplace charging
#      – Smart chargers and managed charging platforms to shift demand to off-peak hours.
#      – Vehicle-to-grid (V2G) pilot projects offering grid‐stabilization services.
#    • Energy integration
#      – Co-location of solar+storage with charging stations.
#      – Utilities launching dedicated EV tariffs and demand-response programs.
#
# 5. Challenges
#    • Raw-material supply chain
#      – Competition for lithium, cobalt, nickel; risk of price volatility and geopolitical concentration.
#      – Recycling and second-use (stationary storage) as partial mitigation.
#    • Grid impact and capacity
#      – Local distribution upgrades needed in high-adoption corridors.
#      – Need for coordinated planning between utilities, governments and fleet operators.
#    • Consumer concerns
#      – Range anxiety persists for long-distance travel, despite growing fast-charge network density.
#      – Upfront sticker price gap still exists on entry-level models.
#
# 6. Future Prospects
#    • Market forecasts
#      – IEA projects EVs to reach 30–50 percent of global new-car sales by 2030 under current policy pathways.
#      – Some regions (e.g., Northern Europe, California) may exceed 70 percent EV share by end of decade.
#    • Technology breakthroughs
#      – Commercial solid-state battery deployments around 2028–2030 could accelerate cost reductions below 80 USD/kWh.
#      – Wireless charging and standardized battery-swap systems in select urban fleets.
#    • Vehicle segments and use cases
#      – Commercial light and heavy-duty vehicles: electrification rates poised to accelerate, driven by total-cost-of-operation advantages.
#      – Autonomous ride-hailing fleets: synergy with EVs for lower per-mile costs and simplified maintenance.
#    • Energy system integration
#      – Broad adoption of V2G/vehicle-to-home (V2H) for peak shaving and emergency backup.
#      – Bidirectional charging business models for prosumers.
#    • Policy and business model innovation
#      – Pay-per-mile or subscription EV ownership to reduce upfront barriers.
#      – Carbon pricing and stricter ICE emissions standards driving faster fleet turnover.
#
# Conclusion
# The EV market is transitioning from early-adopter niche to mainstream mobility. Continued battery-technology improvements, scaling of charging infrastructure, and stronger policy push are converging to lower costs and increase convenience. Over the next decade, EVs are set to become dominant in most developed markets and increasingly prevalent in emerging economies, reshaping automotive manufacturing, energy systems, and mobility services on a global scale.
# --------------------------------------------------
# **MarketResearcher**
# Below is a high-level market-research–style analysis of the global electric-vehicle (EV) market, covering its current state, key drivers and barriers, competitive landscape, and future prospects.
#
# 1. Market Overview and Current State
#    • Market Size & Growth
#      – Global EV sales exceeded 14 million units in 2023, up roughly 40 % year-on-year, and represented an estimated 14 % of all new passenger‐vehicle registrations.
#      – The total addressable market (TAM) for EVs (including passenger cars, light commercial vehicles, and two‐/three-wheelers) is valued at over USD 500 billion in factory gate revenues.
#    • Regional Dynamics
#      – China remains the largest single market (~60 % of global volumes), led by domestic brands (BYD, SAIC, Geely).
#      – Europe accounts for ~20 % of sales, driven by stringent CO₂ targets and purchase incentives (Norway 80 % EV share new sales, Germany ~20 %).
#      – North America (mainly U.S.) has seen accelerated growth post-2022 thanks to the Inflation Reduction Act subsidies.
#      – Emerging markets (India, Southeast Asia, Latin America) are in early adoption phases, with incentives and low‐speed EVs forming the beachhead.
#
# 2. Key Market Drivers
#    • Regulatory & Policy Support
#      – CO₂ emissions standards in EU, U.S. tailpipe regulations, China’s New Energy Vehicle (NEV) quotas.
#      – Purchase incentives, tax credits, congestion-charge exemptions.
#    • Cost Parity & Total-Cost-of-Ownership (TCO)
#      – Battery pack costs declined from > USD 1,200/kWh in 2010 to ~ USD 130–150/kWh in 2023; approaching parity with ICE powertrains in many markets by 2025–26.
#      – Lower maintenance and energy costs boost fleet operator and private-owner economics.
#    • Charging Infrastructure Expansion
#      – > 2 million public chargers worldwide (up ~ 30 % YoY in 2023).
#      – Rapid buildout of fast‐charging corridors in EU and China; U.S. lags but improving under federal funding.
#    • Consumer Attitudes & Brand Innovation
#      – Rising environmental awareness, urban low-emission zones, and the “tech” appeal of EVs.
#      – Premium players (Tesla, Lucid, Mercedes-EQ) and mainstream OEMs (VW ID series, GM Ultium, Hyundai Ioniq) competing on range, performance, and software.
#
# 3. Market Restraints & Challenges
#    • Supply-Chain Bottlenecks
#      – Critical minerals (lithium, cobalt, nickel) face geographic concentration, potential geopolitical risk, and inflationary pressure.
#      – Battery-grade material refining and recycling capacity still catching up.
#    • Charging Accessibility & Standards
#      – Uneven charger density in rural and developing regions; interoperability issues between networks.
#    • Consumer Concerns
#      – Range anxiety persists for some segments.
#      – Residual-value uncertainty in early-adopter cohorts.
#    • Competition from Alternative Powertrains
#      – Plug-in hybrids (PHEVs), hydrogen fuel-cell EVs (FCEVs) in heavy-duty niches, and synthetic e-fuels for legacy ICEs.
#
# 4. Competitive Landscape
#    • Vertically Integrated Players
#      – Tesla leads on software, Supercharger network, and direct sales.
#      – BYD leverages in-house battery and EV manufacturing scale to undercut competitors on price.
#    • Traditional OEMs
#      – Volkswagen Group invests > EUR 100 billion through 2030, with dedicated EV platforms (MEB, PPE).
#      – GM, Ford, Stellantis rolling out multi-brand EV lineups built on Ultium, e-CMP, STLA platforms.
#    • New Entrants & Start-ups
#      – Rivian focusing on premium EV trucks/SUVs, Lucid on luxury sedans, XPeng and NIO in China with service‐focused models.
#
# 5. Future Prospects & Forecasts
#    • Volume & Share Projections
#      – By 2030, global EV sales are projected to reach 25–30 million units annually, capturing 25–35 % of new‐car registrations.
#      – TCO parity in most markets by mid-decade will accelerate mass‐market adoption.
#    • Technology & Business Model Trends
#      – Battery innovation: solid-state, silicon-anode, fast-charging cells; targeting > 700 km real-world range and sub-10-minute top-ups.
#      – Vehicle-to-Grid (V2G) services and second-life battery reuse unlocking new value‐streams.
#      – Software-defined vehicles: OTA updates, subscription features (autonomy, premium audio, enhanced safety).
#    • Infrastructure & Energy Ecosystem
#      – Integration with renewables, smart-charging, and microgrid applications.
#      – Private investment (oil majors entering charging), public-private partnerships to close “last-mile” gaps.
#    • Emerging Segments
#      – Electrified commercial fleets (last-mile delivery, ride-hail, light trucks) forecasted to exceed 10 % penetration by 2028.
#      – Two- and three-wheelers in Asia/Latin America will double in unit sales by 2030, driven by affordability and urban regulations.
#
# 6. Strategic Implications for Stakeholders
#    • OEMs & Tier-1 Suppliers
#      – Accelerate platform rationalization toward modular, scalable EV architectures.
#      – Secure upstream raw-material access through joint ventures and recycling partnerships.
#    • Charging-Network Operators & Utilities
#      – Prioritize strategic corridor deployments and roaming agreements to reduce fragmentation.
#      – Develop bundled energy-as-a-service offerings for fleets and multi‐unit dwellings.
#    • Investors & Private Equity
#      – Target battery-tech innovators and software/Mobility-as-a-Service (MaaS) enablers.
#      – Monitor policy shifts in key markets (EU carbon border adjustment, U.S. MPG/Credit rules).
#    • Policymakers & Regulators
#      – Balance purchase subsidies with charging infrastructure mandates and grid-upgrades.
#      – Harmonize safety and technical standards to support cross-border interoperability.
#
# Conclusion
# The EV market is transitioning from early‐adopter discipline to mainstream scale. Regulatory momentum, technological cost declines, and consumer acceptance point to sustained double-digit growth over the next decade. Success will hinge on managing supply-chain risks, closing charging-infrastructure gaps, and advancing next-gen battery technologies. Stakeholders that align business models with these structural trends stand to capture outsized value as the mobility ecosystem electrifies.
# --------------------------------------------------

# %% [markdown]
# ### 2.3 Concurrent Orchestration with Structured Outputs
#
# You can combine concurrent orchestration with structured outputs for consistent results.

# %%
# Define structured output for research
class ResearchInsight(BaseModel):
    """Research insight with key findings."""
    key_finding: str
    supporting_evidence: str
    implications: str

class ResearchPerspectives(BaseModel):
    """Combined research perspectives."""
    technology: ResearchInsight
    market: ResearchInsight

# Create structured concurrent orchestration
structured_concurrent = ConcurrentOrchestration[str, ResearchPerspectives](
    members=research_agents,
    output_transform=structured_outputs_transform(ResearchPerspectives, chat_completion),
)

print("✅ Structured concurrent orchestration created!")
# Out:
# ✅ Structured concurrent orchestration created!

# %%
# Test structured concurrent orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Structured Research: AI in Healthcare")
print("=" * 50)

try:
    orchestration_result = await structured_concurrent.invoke(
        task="Research AI applications in healthcare. Provide key finding, evidence, and implications.",
        runtime=runtime,
    )
    
    result = await orchestration_result.get(timeout=60)
    
    if isinstance(result, ResearchPerspectives):
        print("📊 Structured Research Results:")
        print(result.model_dump_json(indent=2))
    else:
        print(f"⚠️ Unexpected result type: {type(result)}")
        
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Structured Research: AI in Healthcare
# ==================================================
# 📊 Structured Research Results:
# {
#   "technology": {
#     "key_finding": "AI algorithms in healthcare demonstrate high performance in diagnostic imaging, drug discovery, predictive analytics, precision medicine, patient engagement, and administrative automation when integrated with clinical workflows and governance frameworks.",
#     "supporting_evidence": "A 2020 Radiology meta-analysis reported AUCs of 0.94–0.97 for pneumonia detection on chest X-rays; Insilico Medicine identified a novel DDR1 kinase inhibitor in 46 days versus 18–24 months industry average; the TREWS early-warning system cut sepsis mortality by ~20%; DeepVariant called single nucleotide variants with >99% accuracy; a diabetes-management chatbot improved HbA1c by 0.5%; AI-assisted coding tools reduced claim denials by 30%.",
#     "implications": "Enables early screening and workload reduction, accelerates R&D and lowers costs, supports proactive interventions and personalized therapies, improves patient adherence and administrative efficiency; requires robust clinical validation, seamless EHR/PACS integration, continuous performance monitoring, and strong data-governance and regulatory frameworks."
#   },
#   "market": {
#     "key_finding": "The global AI in healthcare market is rapidly expanding across diagnostic imaging, predictive analytics, drug discovery, precision medicine, robotic and virtual care, administrative automation, and mental-health applications.",
#     "supporting_evidence": "Market projected to grow from $12.1 B in 2021 to $67.4 B by 2028 (CAGR ~26%); FDA lists over 500 AI/ML device submissions with ~150 approvals; Epic’s sepsis model reduced ICU stays by 18%; UiPath deployments cut billing-cycle time by 60%; Woebot delivered a 45% reduction in depressive symptoms.",
#     "implications": "Providers and payers should form partnerships with tech vendors and startups, invest in data infrastructure and governance, pilot high-ROI AI use cases (imaging, claims automation) before enterprise rollouts, engage clinicians early for adoption, and address interoperability, ethical, and regulatory challenges."
#   }
# }

# %% [markdown]
# ### 2.4 Sequential Orchestration
#
# Sequential orchestration passes the output of one agent as input to the next, creating a pipeline.

# %%
def create_product_pipeline() -> list[Agent]:
    """Create a product development pipeline."""
    
    researcher = ChatCompletionAgent(
        name="ProductResearcher",
        instructions="You analyze product ideas and identify key features, target audience, and market opportunities.",
        service=chat_completion,
    )
    
    designer = ChatCompletionAgent(
        name="ProductDesigner",
        instructions="You create product concepts and specifications based on research insights.",
        service=chat_completion,
    )
    
    marketer = ChatCompletionAgent(
        name="ProductMarketer",
        instructions="You create marketing strategies and compelling messaging based on product designs.",
        service=chat_completion,
    )
    
    return [researcher, designer, marketer]

# Create sequential orchestration
product_pipeline = create_product_pipeline()
sequential_orchestration = SequentialOrchestration(
    members=product_pipeline
)

print("✅ Sequential orchestration created!")
# Out:
# ✅ Sequential orchestration created!

# %%
# Test sequential orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Streaming Product Pipeline: Smart Home Security Device")
print("=" * 60)

try:
    orchestration_result = await sequential_orchestration.invoke(
        task="Develop a smart home security device that uses AI for threat detection.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get(timeout=120)
    print(f"\n**Final Marketing Strategy**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Analysis Agent with Tools: Smart Home Security Device
# ============================================================
#
# **Final Marketing Strategy**
# Below is a high-level go-to-market framework plus a suite of messaging assets you can adapt for sales collateral, digital ads and presentations. Feel free to pull what you need and let me know if you’d like deeper detail on any section.
#
# 1. Target Segments & Positioning
#    • Facility & Safety Managers in high-rise offices, hotels, hospitals, manufacturing plants
#    • Construction sites and industrial plants (contractors, QHSE teams)
#    • Education, elder-care and residential-complex operators
#    • Premium consumer segment (outdoor enthusiasts, high-risk hobbyists)
#
#    Positioning Statement
#    “The world’s first wearable, multi-hazard evacuation device that cushions bodily impact, purifies life-saving air and automatically guides you to safety—even in zero-visibility emergencies.”
#
# 2. Core Value Proposition and Messaging Pillars
#    1) Proactive Threat Response
#       – Instant hazard detection (smoke, high heat, toxic gas)
#       – Automatic fan-powered airflow clears your breathing path
#    2) Impact Absorption & Fall Protection
#       – Ultra-fast airbag inflation to shield head and torso
#       – Integrated impact sensors notify emergency contacts
#    3) Smart Guidance & Connectivity
#       – Voice-guided egress instructions, live location sharing
#       – Cloud-based incident logs for after-action review
#
# 3. Campaign Themes & Channels
#    A. Digital Lead Generation
#       – LinkedIn/Google Ads targeting “EHS Manager,” “Facilities Director”
#       – Thought-leadership whitepaper: “Reinventing Personal Evacuation” gated download
#    B. Trade Shows & Field Demos
#       – Booth with live drop tests, smoke-filled maze for hands-on demos
#       – Partnerships with OSHA/ANSI for demonstration validity
#    C. Strategic Partnerships
#       – Co-branding with large building-automation providers
#       – Insurance carriers: offer premium discounts to policyholders using the device
#    D. Content & PR
#       – Video case study: “How the XYZ Bank saved 22 lives in minutes”
#       – Press release for first UL certification on wearable evacuation airbags
#
# 4. Pricing & Packaging
#    • Tier 1 – Core Unit: impact-airbag + fan + hazard detection
#    • Tier 2 – Pro: adds GPS tracking, two-way voice guidance, cloud dashboard
#    • Annual service & data subscription (firmware updates, analytics portal)
#    • Pilot-program bundles: test 50 units at 20% discount, no-risk 30-day return
#
# 5. Timeline & KPIs
#    Month 1–2
#      – Finalize pricing, pilot agreements, collateral
#      – Launch paid‐search and LinkedIn campaigns
#    Month 3–4
#      – Attend 2 major industry expos, conduct on-site demos
#      – Publish whitepaper, secure 3 thought-lead speaking slots
#    Month 5–6
#      – Secure 5 enterprise pilots (≥100 units)
#      – Drive 200 qualified leads, 10% conversion rate
#
#    Key Metrics
#      – Website visits & lead gen form fills
#      – Pilot-program enrollments
#      – Average deal size and sales cycle length
#      – Customer satisfaction (post-pilot NPS)
#
# 6. Sample Messaging Assets
#
#   A) Elevator Pitch (30 seconds)
#   “Imagine a device you strap on every day that instantly senses smoke or toxic gas, blasts clean air so you can breathe in seconds, inflates a protective cushion if you fall, and talks you out of danger with live guidance—then logs the entire event to the cloud so you know exactly what happened. That’s [ProductName], the first all-in-one wearable evacuation system.”
#
#   B) One-Line Taglines
#    – “Breathe. Cushion. Escape.”
#    – “Your Last Line of Defense in Every Emergency.”
#    – “From Detection to Egress—Complete Personal Safety.”
#
#   C) Features→Benefits Bullets (for datasheet or website)
#     • Multi-Sensor Hazard Detection → Know danger before it’s too late
#     • High-Flow Air Purification Fan → Instant clear breathing path
#     • 0.2-sec Airbag Inflation → Head-to-torso impact protection
#     • Voice-Guided Route Navigation → Hands-free exit in zero visibility
#     • Cloud-Connected Incident Logs → Audit trails for compliance & training
#
#   D) Social-Media Ad Copy (LinkedIn Sponsored Post)
#     “Facilities teams: are you still relying on fire-drills and gas masks? Meet [ProductName]—your wearable evacuation system that senses hazards, inflates on impact and literally talks you to safety. Book a free demo today.”
#
# Next Steps
#  • Review & select your priority segments and campaign themes
#  • Lock in pilot customers and finalize pricing structure
#  • Develop detailed creative assets (videos, slide decks, datasheets)
#  • Kick off the digital lead-gen engine and AV demo tour
#
# Let me know which pillars you’d like to expand (pricing deep-dive, creative storyboard, detailed channel plan, etc.), and I’ll build it out.

# %% [markdown]
# ### 2.5 Streaming and intermediate results with Orchestration
#
# Lets looks at how you can use streaming and observe intermediate results with the sequential pattern. This will work for other orchestration patterns too.

# %%
# Global variable to track streaming state
is_new_message = True

def streaming_agent_response_callback(message: StreamingChatMessageContent, is_final: bool) -> None:
    """Handle streaming responses from agents."""
    global is_new_message
    
    if is_new_message:
        print(f"\n**{message.name}**")
        is_new_message = False
        
    print(message.content, end="", flush=True)
    
    if is_final:
        print("\n" + "-" * 50)
        is_new_message = True
        
def agent_response_callback(message: ChatMessageContent) -> None:
    """Handle support agent responses."""
    # print(f"**{message.name}**: {message.content}")
    
    # Show function calls
    for item in message.items:
        if isinstance(item, FunctionCallContent):
            print(f"  📞 Calling: {item.name}({item.arguments})")
        elif isinstance(item, FunctionResultContent):
            print(f"  📋 Result: {item.result}")
    print("-" * 50)


summarizer_agent = ChatCompletionAgent(
    service=chat_completion,
    name="Summarizer",
    instructions="You summarize results in no more than 100 words.",
)

# Create streaming sequential orchestration
streaming_sequential = SequentialOrchestration(
    members=[analysis_agent, summarizer_agent], ## Resusing reasoning agent for demonstration purposes.
    streaming_agent_response_callback=streaming_agent_response_callback,
    agent_response_callback=agent_response_callback
)

print("✅ Streaming sequential orchestration created!")
# Out:
# ✅ Streaming sequential orchestration created!

# %%
# Test streaming sequential orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Analysis Agent with Tools: Fitness Wearable")
print("=" * 60)

try:
    orchestration_result = await streaming_sequential.invoke(
        task="Create a fitness wearable that tracks mental wellness alongside physical health.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get(timeout=120)
    print(f"\n\n**Final Pipeline Result**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()
# Out:
# 🎯 Analysis Agent with Tools: Fitness Wearable
# ============================================================
#   📞 Calling: AnalysisPlugin-analyze_topic({"topic":"Fitness wearable that tracks mental wellness alongside physical health"})
# --------------------------------------------------
#
# **AnalysisExpert**
#
# --------------------------------------------------
#   📋 Result: Analysis of 'Fitness wearable that tracks mental wellness alongside physical health': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility.
# --------------------------------------------------
#
# **AnalysisExpert**
#
# --------------------------------------------------
#
# **AnalysisExpert**
#   📞 Calling: AnalysisPlugin-generate_recommendations({"analysis":"Analysis of 'Fitness wearable that tracks mental wellness alongside physical health': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility."})
# --------------------------------------------------
#
# --------------------------------------------------
#   📋 Result: Recommendations: 1) Conduct further research, 2) Develop a prototype, 3) Test with users, 4) Iterate based on feedback.
# --------------------------------------------------
#
# **AnalysisExpert**
#
# --------------------------------------------------
#
# **AnalysisExpert**
# Based on our in-depth analysis, here are the key recommendations for creating a fitness wearable that tracks mental wellness alongside physical health:
#
# 1. Conduct Market & User Research
#    • Survey target demographics to understand priorities for mental-health tracking (stress, mood, focus, relaxation).
#    • Analyze competitors (e.g., Fitbit, Apple Watch, Oura Ring) to identify gaps in their mental-wellness features.
#    • Collaborate with psychologists and mental-health professionals to determine clinically validated metrics.
#
# 2. Define Core Features & Metrics
#    • Physical Health: heart rate, activity levels, sleep stages, calories burned.
#    • Mental Wellness: stress detection (via heart rate variability), mood logging (user prompts), breath-rate analytics, guided breathing sessions.
#    • Contextual Triggers: location, time of day, and activity patterns to prompt mindfulness check-ins.
#
# 3. Technical Feasibility & Prototype
#    • Hardware: select sensors (PPG for HR/HRV, accelerometer, gyroscope) and ensure comfortable form factor.
#    • Firmware/Software: develop algorithms for stress detection, mood inference, and sleep-quality scoring.
#    • Mobile App: intuitive UI for real-time dashboards, historical trends, and personalized recommendations.
#
# 4. Validation & Testing
#    • Pilot Studies: recruit a small cohort to evaluate sensor accuracy and algorithm reliability.
#    • Usability Testing: assess the user interface for ease of logging moods, interpreting data, and following guided exercises.
#    • Data Privacy & Compliance: ensure GDPR/HIPAA adherence, provide transparent data-consent flows, and secure encryption.
#
# 5. Iteration & Partnerships
#    • Iterate based on user feedback—adjust sensor sensitivity, refine algorithms, enhance UI/UX flows.
#    • Partner with mental-health apps (e.g., Headspace, Calm) for integrated guided mindfulness sessions.
#    • Explore employer wellness programs and healthcare integrations for broader adoption.
#
# 6. Go-to-Market Strategy
#    • Positioning: emphasize the dual focus on mental wellness + fitness, differentiation from purely physical trackers.
#    • Pricing & Monetization: device sale plus optional subscription for advanced analytics and coaching.
#    • Marketing: leverage case studies showing improved well-being, influencer partnerships, and targeted digital campaigns.
#
# By following these steps—grounded in research, validated through testing, and iteratively refined—you’ll be well-positioned to launch a next-generation fitness wearable that meaningfully supports both physical health and mental well-being.
# --------------------------------------------------
# --------------------------------------------------
#
# **Summarizer**
# Conduct market and user research (with psychologists) to pinpoint mental-wellness metrics. Define core features: HR/HRV, sleep, activity sensors; mood logging; guided breathing. Prototype hardware, firmware, and mobile UI. Validate via pilot studies and usability tests while ensuring GDPR/HIPAA compliance. Iterate on user feedback, refine algorithms, and partner with mental-health apps. Launch with a dual physical/mental-wellness focus, device sales plus subscription, and targeted marketing using case studies and influencers.
# --------------------------------------------------
# --------------------------------------------------
#
#
# **Final Pipeline Result**
# Conduct market and user research (with psychologists) to pinpoint mental-wellness metrics. Define core features: HR/HRV, sleep, activity sensors; mood logging; guided breathing. Prototype hardware, firmware, and mobile UI. Validate via pilot studies and usability tests while ensuring GDPR/HIPAA compliance. Iterate on user feedback, refine algorithms, and partner with mental-health apps. Launch with a dual physical/mental-wellness focus, device sales plus subscription, and targeted marketing using case studies and influencers.

# %% [markdown]
# ## 3. Custom Group Chat Manager
#
# For more sophisticated group interactions, you can create custom group chat managers that use AI to decide who speaks next.

# %%
class AIGroupChatManager(GroupChatManager):
    """AI-powered group chat manager that decides who speaks next."""
    
    def __init__(self, topic: str, service, **kwargs):
        super().__init__(**kwargs)
        self.topic = topic
        self.service = service
        self.max_rounds = kwargs.get('max_rounds', 6)
        self.current_round = 0
    
    async def _render_prompt(self, prompt: str, arguments: KernelArguments) -> str:
        """Helper to render prompts with arguments."""
        config = PromptTemplateConfig(template=prompt)
        template = KernelPromptTemplate(prompt_template_config=config)
        return await template.render(Kernel(), arguments=arguments)
    
    @override
    async def should_request_user_input(self, chat_history: ChatHistory) -> BooleanResult:
        """This manager doesn't require user input."""
        return BooleanResult(result=False, reason="No user input required.")
    
    @override
    async def should_terminate(self, chat_history: ChatHistory) -> BooleanResult:
        """Determine if the discussion should end."""
        self.current_round += 1
        
        if self.current_round >= self.max_rounds:
            return BooleanResult(result=True, reason="Maximum rounds reached.")
        
        # Simple termination based on round count
        return BooleanResult(result=False, reason="Discussion continues.")
    
    @override
    async def select_next_agent(
        self, chat_history: ChatHistory, participant_descriptions: dict[str, str]
    ) -> StringResult:
        """Select the next agent to speak."""
        # Simple round-robin selection for this example
        agent_names = list(participant_descriptions.keys())
        selected_agent = agent_names[self.current_round % len(agent_names)]
        
        return StringResult(
            result=selected_agent,
            reason=f"Selected {selected_agent} for round {self.current_round}"
        )
    
    @override
    async def filter_results(self, chat_history: ChatHistory) -> MessageResult:
        """Filter and summarize the discussion results."""
        summary = f"Discussion on '{self.topic}' completed after {self.current_round} rounds."
        
        return MessageResult(
            result=ChatMessageContent(role=AuthorRole.ASSISTANT, content=summary),
            reason="Discussion summarized"
        )

print("✅ Custom AI Group Chat Manager created!")
# Out:
# ✅ Custom AI Group Chat Manager created!

# %%
# Create debate agents
def create_debate_agents() -> list[Agent]:
    """Create agents for a debate scenario."""
    
    optimist = ChatCompletionAgent(
        name="TechOptimist",
        description="A technology optimist who believes in AI's positive potential.",
        instructions="You believe AI will greatly benefit humanity. Present positive arguments with specific examples.",
        service=chat_completion,
    )
    
    skeptic = ChatCompletionAgent(
        name="TechSkeptic",
        description="A technology skeptic who is concerned about AI risks.",
        instructions="You are concerned about AI risks and challenges. Present thoughtful counterarguments.",
        service=chat_completion,
    )
    
    return [optimist, skeptic]

# Create custom group chat
debate_agents = create_debate_agents()
custom_group_chat = GroupChatOrchestration(
    members=debate_agents,
    manager=AIGroupChatManager(
        topic="The Future of AI in Society",
        service=chat_completion,
        max_rounds=4,
    ),
    agent_response_callback=agent_response_callback,
)

print("✅ Custom group chat for debate created!")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[59], line 25
#      21 # Create custom group chat
#      22 debate_agents = create_debate_agents()
#      23 custom_group_chat = GroupChatOrchestration(
#      24     members=debate_agents,
# ---> 25     manager=AIGroupChatManager(
#      26         topic="The Future of AI in Society",
#      27         service=chat_completion,
#      28         max_rounds=4,
#      29     ),
#      30     agent_response_callback=agent_response_callback,
#      31 )
#      33 print("✅ Custom group chat for debate created!")
#
# Cell In[58], line 6, in AIGroupChatManager.__init__(self, topic, service, **kwargs)
#       4 def __init__(self, topic: str, service, **kwargs):
#       5     super().__init__(**kwargs)
# ----> 6     self.topic = topic
#       7     self.service = service
#       8     self.max_rounds = kwargs.get('max_rounds', 6)
#
# File ~/lseg-migration-agent/.venv/lib/python3.12/site-packages/pydantic/main.py:998, in BaseModel.__setattr__(self, name, value)
#     996 # if None is returned from _setattr_handler, the attribute was set directly
#     997 elif (setattr_handler := self._setattr_handler(name, value)) is not None:
# --> 998     setattr_handler(self, name, value)  # call here to not memo on possibly unknown fields
#     999     self.__pydantic_setattr_handlers__[name] = setattr_handler
#
# File ~/lseg-migration-agent/.venv/lib/python3.12/site-packages/pydantic/main.py:114, in <lambda>(model, name, val)
#     108         object.__setattr__(model, '__pydantic_private__', {})
#     109     model.__pydantic_private__[name] = val  # pyright: ignore[reportOptionalSubscript]
#     112 _SIMPLE_SETATTR_HANDLERS: Mapping[str, Callable[[BaseModel, str, Any], None]] = {
#     113     'model_field': _model_field_setattr_handler,
# --> 114     'validate_assignment': lambda model, name, val: model.__pydantic_validator__.validate_assignment(model, name, val),  # pyright: ignore[reportAssignmentType]
#     115     'private': _private_setattr_handler,
#     116     'cached_property': lambda model, name, val: model.__dict__.__setitem__(name, val),
#     117     'extra_known': lambda model, name, val: _object_setattr(model, name, val),
#     118 }
#     121 class BaseModel(metaclass=_model_construction.ModelMetaclass):
#     122     """!!! abstract "Usage Documentation"
#     123         [Models](../concepts/models.md)
#     124
#    (...)    151         __pydantic_private__: Values of private attributes set on the model instance.
#     152     """
#
# ValidationError: 1 validation error for AIGroupChatManager
# topic
#   Object has no attribute 'topic' [type=no_such_attribute, input_value='The Future of AI in Society', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/no_such_attribute

# %%
# Test custom group chat
runtime = InProcessRuntime()
runtime.start()

print("🎯 AI Debate: The Future of AI in Society")
print("=" * 60)

try:
    orchestration_result = await custom_group_chat.invoke(
        task="Discuss the benefits and risks of AI integration in society.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get()
    print(f"\n**Debate Summary**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()

# %% [markdown]
# ## 4. Handoff Orchestration
#
# Handoff orchestration allows agents to transfer conversations to specialized agents based on the context.

# %%
# Create specialized support plugins
class TechnicalSupportPlugin:
    """Plugin for technical support tasks."""
    
    @kernel_function(description="Diagnose technical issues.")
    def diagnose_issue(self, issue: Annotated[str, "Description of the technical issue"]) -> str:
        return f"Diagnosis for '{issue}': This appears to be a common connectivity issue. Try restarting your device and checking your network connection."
    
    @kernel_function(description="Provide troubleshooting steps.")
    def troubleshoot(self, diagnosis: Annotated[str, "The diagnosis result"]) -> str:
        return "Troubleshooting steps: 1) Restart device, 2) Check network, 3) Update software, 4) Contact support if issue persists."

class BillingSupportPlugin:
    """Plugin for billing support tasks."""
    
    @kernel_function(description="Check billing information.")
    def check_billing(self, account_id: Annotated[str, "Account ID"]) -> str:
        return f"Billing info for account {account_id}: Current balance: $45.99, Next payment due: 2024-02-15"
    
    @kernel_function(description="Process payment.")
    def process_payment(self, amount: Annotated[str, "Payment amount"]) -> str:
        return f"Payment of {amount} processed successfully. Thank you!"

print("✅ Support plugins created!")

# %%
# Create specialized support agents
triage_agent = ChatCompletionAgent(
    name="SupportTriage",
    description="A triage agent that routes customers to appropriate specialists.",
    instructions="You help customers by understanding their needs and routing them to the right specialist. Be friendly and efficient.",
    service=chat_completion,
)

tech_support_agent = ChatCompletionAgent(
    name="TechSupport",
    description="A technical support specialist.",
    instructions="You provide technical support and troubleshooting. Use your tools to diagnose and solve problems.",
    service=chat_completion,
    plugins=[TechnicalSupportPlugin()],
)

billing_support_agent = ChatCompletionAgent(
    name="BillingSupport",
    description="A billing support specialist.",
    instructions="You handle billing questions and payment processing. Use your tools to help with account issues.",
    service=chat_completion,
    plugins=[BillingSupportPlugin()],
)

print("✅ Support agents created!")

# %%
# Define handoff relationships
handoffs = (
    OrchestrationHandoffs()
    .add_many(
        source_agent=triage_agent.name,
        target_agents={
            tech_support_agent.name: "Transfer to this agent for technical issues and troubleshooting",
            billing_support_agent.name: "Transfer to this agent for billing, payment, and account issues",
        },
    )
    .add(
        source_agent=tech_support_agent.name,
        target_agent=triage_agent.name,
        description="Transfer back to triage if the issue is not technical",
    )
    .add(
        source_agent=billing_support_agent.name,
        target_agent=triage_agent.name,
        description="Transfer back to triage if the issue is not billing-related",
    )
)

print("✅ Handoff relationships defined!")

# %%
# Create handoff orchestration
def support_response_callback(message: ChatMessageContent) -> None:
    """Handle support agent responses."""
    print(f"**{message.name}**: {message.content}")
    
    # Show function calls
    for item in message.items:
        if isinstance(item, FunctionCallContent):
            print(f"  📞 Calling: {item.name}({item.arguments})")
        elif isinstance(item, FunctionResultContent):
            print(f"  📋 Result: {item.result}")
    print("-" * 50)

handoff_orchestration = HandoffOrchestration(
    members=[
        triage_agent,
        tech_support_agent,
        billing_support_agent,
    ],
    handoffs=handoffs,
    agent_response_callback=support_response_callback,
)

print("✅ Handoff orchestration created!")

# %%
# Test handoff orchestration
runtime = InProcessRuntime()
runtime.start()

print("🎯 Customer Support Scenario: Technical Issue")
print("=" * 60)

try:
    orchestration_result = await handoff_orchestration.invoke(
        task="Hi, I'm having trouble connecting to the internet. My device keeps disconnecting.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get()
    print(f"\n**Support Resolution**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()

# %% [markdown]
# ## 5. Human-in-the-Loop Systems
#
# Sometimes you need human input during agent interactions. Here's how to implement human-in-the-loop systems.

# %%
# Custom manager that requests human input
class HumanInTheLoopManager(RoundRobinGroupChatManager):
    """Manager that requests human input after specific conditions."""
    
    @override
    async def should_request_user_input(self, chat_history: ChatHistory) -> BooleanResult:
        """Request user input after every 2 agent exchanges."""
        agent_messages = [msg for msg in chat_history.messages if msg.role == AuthorRole.ASSISTANT]
        
        if len(agent_messages) >= 2 and len(agent_messages) % 2 == 0:
            return BooleanResult(
                result=True,
                reason="Requesting user feedback after agent exchanges"
            )
        
        return BooleanResult(
            result=False,
            reason="No user input needed yet"
        )

# Simple human response function for demonstration
def get_human_response(chat_history: ChatHistory) -> ChatMessageContent:
    """Get human input (simulated for this example)."""
    # In a real application, this would get actual user input
    responses = [
        "That's interesting! Can you elaborate on the benefits?",
        "I like the first approach better. Can you refine it?",
        "Good work! Please finalize the solution."
    ]
    
    # Simulate human response based on conversation length
    response_index = min(len(chat_history.messages) // 4, len(responses) - 1)
    human_input = responses[response_index]
    
    print(f"👤 Human: {human_input}")
    return ChatMessageContent(role=AuthorRole.USER, content=human_input)

print("✅ Human-in-the-loop components created!")

# %%
# Create collaborative agents
def create_collaborative_agents() -> list[Agent]:
    """Create agents that work well with human feedback."""
    
    strategist = ChatCompletionAgent(
        name="Strategist",
        description="A strategic planner.",
        instructions="You develop high-level strategies and adapt based on feedback. Be responsive to human input.",
        service=chat_completion,
    )
    
    implementer = ChatCompletionAgent(
        name="Implementer",
        description="A solution implementer.",
        instructions="You create detailed implementation plans based on strategies. Incorporate human feedback.",
        service=chat_completion,
    )
    
    return [strategist, implementer]

# Create human-in-the-loop orchestration
collaborative_agents = create_collaborative_agents()
human_loop_orchestration = GroupChatOrchestration(
    members=collaborative_agents,
    manager=HumanInTheLoopManager(
        max_rounds=6,
        human_response_function=get_human_response,
    ),
    agent_response_callback=agent_response_callback,
)

print("✅ Human-in-the-loop orchestration created!")

# %%
# Test human-in-the-loop system
runtime = InProcessRuntime()
runtime.start()

print("🎯 Collaborative Project: Remote Team Productivity")
print("=" * 60)

try:
    orchestration_result = await human_loop_orchestration.invoke(
        task="Develop a strategy to improve remote team productivity and collaboration.",
        runtime=runtime,
    )
    
    final_result = await orchestration_result.get()
    print(f"\n**Final Collaborative Solution**")
    print(final_result)
    
finally:
    await runtime.stop_when_idle()

# %% [markdown]
# ## 6. Production Considerations
#
# When building production systems, consider these important aspects:

# %% [markdown]
# ### 6.1 Error Handling
#
# Implement robust error handling for production systems.

# %%
import logging
from typing import Optional

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

class RobustAgent:
    """Agent wrapper with error handling and retries."""
    
    def __init__(self, agent: ChatCompletionAgent, max_retries: int = 3):
        self.agent = agent
        self.max_retries = max_retries
    
    async def get_response_with_retry(self, message: str, thread: Optional[ChatHistoryAgentThread] = None) -> Optional[str]:
        """Get response with retry logic and error handling."""
        
        for attempt in range(self.max_retries):
            try:
                logger.info(f"Attempt {attempt + 1} for agent {self.agent.name}")
                
                response = await self.agent.get_response(messages=message, thread=thread)
                logger.info(f"Success: {self.agent.name} responded")
                
                return response.message.content
                
            except Exception as e:
                logger.error(f"Attempt {attempt + 1} failed for {self.agent.name}: {str(e)}")
                
                if attempt == self.max_retries - 1:
                    logger.error(f"All retries exhausted for {self.agent.name}")
                    return None
                
                # Wait before retry
                await asyncio.sleep(2 ** attempt)  # Exponential backoff
        
        return None

# Test error handling
test_agent = ChatCompletionAgent(
    service=chat_completion,
    name="TestAgent",
    instructions="You are a test agent for demonstrating error handling."
)

robust_agent = RobustAgent(test_agent)
response = await robust_agent.get_response_with_retry("Hello, how are you?")

if response:
    print(f"✅ Robust response: {response}")
else:
    print("❌ Failed to get response after retries")

print("✅ Error handling example completed!")

# %% [markdown]
# ### 6.2 Performance Monitoring
#
# Monitor performance metrics for production systems.

# %%
import time
from dataclasses import dataclass
from typing import Dict, List

@dataclass
class PerformanceMetrics:
    """Performance metrics for agent operations."""
    agent_name: str
    operation: str
    start_time: float
    end_time: float
    duration: float
    success: bool
    error_message: Optional[str] = None

class PerformanceMonitor:
    """Monitor and track agent performance."""
    
    def __init__(self):
        self.metrics: List[PerformanceMetrics] = []
    
    async def monitor_agent_call(self, agent: ChatCompletionAgent, message: str) -> Optional[str]:
        """Monitor an agent call and collect metrics."""
        start_time = time.time()
        
        try:
            response = await agent.get_response(messages=message)
            end_time = time.time()
            
            # Record successful metrics
            metrics = PerformanceMetrics(
                agent_name=agent.name,
                operation="get_response",
                start_time=start_time,
                end_time=end_time,
                duration=end_time - start_time,
                success=True
            )
            self.metrics.append(metrics)
            
            return response.message.content
            
        except Exception as e:
            end_time = time.time()
            
            # Record failed metrics
            metrics = PerformanceMetrics(
                agent_name=agent.name,
                operation="get_response",
                start_time=start_time,
                end_time=end_time,
                duration=end_time - start_time,
                success=False,
                error_message=str(e)
            )
            self.metrics.append(metrics)
            
            return None
    
    def get_performance_summary(self) -> Dict[str, any]:
        """Get performance summary statistics."""
        if not self.metrics:
            return {"message": "No metrics collected"}
        
        total_calls = len(self.metrics)
        successful_calls = sum(1 for m in self.metrics if m.success)
        failed_calls = total_calls - successful_calls
        
        durations = [m.duration for m in self.metrics if m.success]
        avg_duration = sum(durations) / len(durations) if durations else 0
        
        return {
            "total_calls": total_calls,
            "successful_calls": successful_calls,
            "failed_calls": failed_calls,
            "success_rate": successful_calls / total_calls if total_calls > 0 else 0,
            "average_duration": avg_duration,
            "max_duration": max(durations) if durations else 0,
            "min_duration": min(durations) if durations else 0,
        }

# Test performance monitoring
monitor = PerformanceMonitor()
test_agent = ChatCompletionAgent(
    service=chat_completion,
    name="PerformanceTestAgent",
    instructions="You are a test agent for performance monitoring."
)

# Make several monitored calls
test_messages = [
    "Hello, how are you?",
    "What's the weather like?",
    "Tell me a joke.",
]

print("📊 Testing performance monitoring...")
for i, message in enumerate(test_messages):
    print(f"Test {i+1}: {message}")
    response = await monitor.monitor_agent_call(test_agent, message)
    if response:
        print(f"Response: {response[:50]}...")
    print("-" * 30)

# Show performance summary
summary = monitor.get_performance_summary()
print("\n📈 Performance Summary:")
for key, value in summary.items():
    print(f"  {key}: {value}")

print("\n✅ Performance monitoring example completed!")

# %% [markdown]
# ### 6.3 Best Practices Summary
#
# Here are key best practices for production Semantic Kernel applications:
#
# #### 🔧 Configuration Management
# - Use environment variables for sensitive configuration
# - Implement configuration validation
# - Support multiple environments (dev, staging, production)
#
# #### 🔍 Monitoring & Logging
# - Implement comprehensive logging for debugging
# - Monitor API usage and costs
# - Track agent performance metrics
# - Set up alerting for failures
#
# #### 🛡️ Security
# - Never log sensitive information
# - Implement proper authentication and authorization
# - Use secure communication channels
# - Validate all inputs and outputs
#
# #### 🚀 Performance
# - Implement caching where appropriate
# - Use concurrent orchestration for parallel tasks
# - Monitor and optimize token usage
# - Implement proper timeout handling
#
# #### 🔄 Reliability
# - Implement retry logic with exponential backoff
# - Handle rate limiting gracefully
# - Provide fallback mechanisms
# - Clean up resources (threads, connections)
#
# #### 📊 Testing
# - Test agent responses with various inputs
# - Implement integration tests for orchestration
# - Test error scenarios and edge cases
# - Monitor agent behavior in production

# %% [markdown]
# ## 7. Cleanup
#
# Always clean up resources when done.

# %%
# Clean up any remaining threads and resources
print("🧹 Cleaning up resources...")

# Note: In a real application, you'd want to track and clean up all threads
# This is a simplified example

print("✅ Cleanup completed!")

# %% [markdown]
# ## 🎉 Congratulations!
#
# You've completed the Advanced Semantic Kernel tutorial! Here's what you've mastered:
#
# ### ✅ Advanced Concepts Covered:
# 1. **Streaming & Intermediate Steps** - Real-time response handling
# 2. **Structured Outputs** - Consistent response formatting with Pydantic
# 3. **Multi-Agent Orchestration** - Complex agent collaboration patterns
# 4. **Group Chat Management** - AI-powered conversation coordination
# 5. **Concurrent Processing** - Parallel agent execution
# 6. **Sequential Workflows** - Pipeline-based processing
# 7. **Handoff Systems** - Specialized agent routing
# 8. **Human-in-the-Loop** - Interactive agent workflows
# 9. **Production Considerations** - Error handling, monitoring, best practices
#
# ### 🚀 What's Next?
# - Build your own multi-agent system for your specific use case
# - Explore more advanced plugins and integrations
# - Implement production monitoring and alerting
# - Experiment with different AI models and configurations
# - Contribute to the Semantic Kernel community
#
# ### 📚 Additional Resources:
# - [Advanced Agent Patterns](https://learn.microsoft.com/en-us/semantic-kernel/agents/patterns/)
# - [Production Deployment Guide](https://learn.microsoft.com/en-us/semantic-kernel/deployment/)
# - [Semantic Kernel Community](https://github.com/microsoft/semantic-kernel/discussions)
# - [Plugin Development Guide](https://learn.microsoft.com/en-us/semantic-kernel/agents/plugins/)
# - [Performance Optimization](https://learn.microsoft.com/en-us/semantic-kernel/concepts/performance/)
#
# ### 🤝 Community
# - Join the [Semantic Kernel Discord](https://discord.gg/semantic-kernel)
# - Follow [@SemanticKernel](https://twitter.com/SemanticKernel) on Twitter
# - Check out the [Developer Blog](https://devblogs.microsoft.com/semantic-kernel/)
#
# Happy building with Semantic Kernel! 🚀🤖
